# %% [markdown]
# ### 請解壓縮data.rar，取得本程式之數據
# ### 訓練資料來自 : http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html

# %%
from google.colab import drive
# %tensorflow_version 1.x
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import scipy.misc as sc 
import math
import cv2
import os
import matplotlib.pyplot as plt

drive.mount('/content/gdrive')
path = os.path.join(os.getcwd() , 'gdrive' , 'My Drive' , 'pix2pix_blur_gan')
os.chdir(path)
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# Mounted at /content/gdrive

# %%
# 讀取訓練與測試資料
img_resize = np.load('images_resize.npy')
img_blur = np.load('images_blur.npy')
real_train = img_resize[:900]
blur_train = img_blur[:900]
real_test = img_resize[900:]
blur_test = img_blur[900:]
del img_resize , img_blur

# %%
def batch_norm_layer_part1(inputs , on_train , convolution):
    # the dimension you wanna normalize, here [0] for batch
    # for image, you wanna do [0 , 1 , 2] for [batch , height , width] but not channel
    if convolution:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0 , 1 , 2] , name = 'mean_var')
    else:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0] , name = 'mean_var')

    ema = tf.train.ExponentialMovingAverage(decay = 0.75)
    ema_apply_op = ema.apply([fc_mean , fc_var])
    mean = tf.cond(on_train , lambda : fc_mean , lambda : ema.average(fc_mean))
    var = tf.cond(on_train , lambda : fc_var , lambda : ema.average(fc_var))
    return mean , var , ema_apply_op

def batch_norm_layer_part2(inputs , mean , var):
    scale = tf.get_variable(shape = inputs.shape[-1].value , initializer = tf.random_normal_initializer(1 , 0.02) , name = 'scale')
    shift = tf.get_variable(shape = inputs.shape[-1].value , initializer = tf.zeros_initializer , name = 'shift')
    temp = (inputs - mean) / tf.sqrt(var + 1e-8)
    outputs = tf.multiply(temp , scale) + shift
    return outputs


def conv_block(inputs , n_filter , layer , kernel_size = 4 , stride = 2 , padding = 'same' ,
               activation_func = tf.nn.leaky_relu , batch_norm = True , reuse = False):
    with tf.variable_scope('Conv{}'.format(layer)) as scope:
        if reuse: tf.get_variable_scope().reuse_variables()
        conv = tf.contrib.layers.conv2d(inputs , n_filter , [kernel_size , kernel_size] ,
                                        stride = stride , padding = padding , activation_fn = None ,
                                        weights_initializer = tf.contrib.layers.xavier_initializer_conv2d(uniform = False))
    if activation_func is not None:
        conv = activation_func(conv)    
    
    if batch_norm:
        with tf.variable_scope('Conv{}_compute_mean_var'.format(layer)):
            conv_mean , conv_var , conv_ema = batch_norm_layer_part1(conv , on_train , True)
        with tf.variable_scope(scope):
            conv = batch_norm_layer_part2(conv , conv_mean , conv_var)

    if batch_norm: 
        return conv , conv_ema
    else:
        return conv


def up_block(inputs , n_filter , layer , kernel_size = 4 , stride = 1 , padding = 'same' ,
             activation_func = tf.nn.relu , batch_norm = True , dropout = False , reuse = False):
    with tf.variable_scope('Up{}'.format(layer)) as scope:
        if reuse: tf.get_variable_scope().reuse_variables()
        up = tf.keras.layers.UpSampling2D(size = [2, 2])(inputs)
        up = tf.contrib.layers.conv2d(up , n_filter , [kernel_size , kernel_size] ,  
                                      stride = stride , padding = padding , activation_fn = None ,
                                      weights_initializer = tf.contrib.layers.xavier_initializer_conv2d(uniform = False))

    if activation_func is not None:
        up = activation_func(up)  

    if batch_norm:
        with tf.variable_scope('Up{}_compute_mean_var'.format(layer)):
            up_mean , up_var , up_ema = batch_norm_layer_part1(up , on_train , True)
        with tf.variable_scope(scope):
            up = batch_norm_layer_part2(up , up_mean , up_var)

    if batch_norm:
        if dropout: up = tf.nn.dropout(up , keep_prob)         
        return up , up_ema
    else:
        return up


def batch_generator(X , y , batch_size):
    size = X.shape[0]
    X_copy = X.copy()
    y_copy = y.copy()
    indices = np.arange(size)
    np.random.shuffle(indices)
    X_copy = X_copy[indices]
    y_copy = y_copy[indices]
    i = 0
    while True:
        if i + batch_size <= size:
            yield X_copy[i : i + batch_size] , y_copy[i : i + batch_size]
            i += batch_size
        else:
            i = 0
            indices = np.arange(size)
            np.random.shuffle(indices)
            X_copy = X_copy[indices]
            y_copy = y_copy[indices]

# %%
eps = 1e-8
g_ema , d_ema = [] , []
blur_img = tf.placeholder(tf.float32 , [None , 256 , 256 , 3] , name = 'blur_img')
real_img = tf.placeholder(tf.float32 , [None , 256 , 256 , 3] , name = 'real_img')
keep_prob = tf.placeholder(tf.float32 , name = 'keep_prob')
on_train = tf.placeholder(tf.bool , name = 'on_train')

# %%
# Generator採用的是UNET的架構
# Generator，相當於偽造家
with tf.variable_scope('Generator'):
    with tf.variable_scope('Encoder_Stage'):
        conv1 = conv_block(blur_img , 64 , 1 , batch_norm = False)
        conv2 , g_en_ema_2 = conv_block(conv1 , 128 , 2)
        conv3 , g_en_ema_3 = conv_block(conv2 , 256 , 3)
        conv4 , g_en_ema_4 = conv_block(conv3 , 512 , 4)
        conv5 , g_en_ema_5 = conv_block(conv4 , 512 , 5)
        conv6 , g_en_ema_6 = conv_block(conv5 , 512 , 6)
        conv7 , g_en_ema_7 = conv_block(conv6 , 512 , 7)
        g_ema.extend([g_en_ema_2 , g_en_ema_3 , g_en_ema_4 , g_en_ema_5 , g_en_ema_6 , g_en_ema_7])

    with tf.variable_scope('Middle_Stage'):    
        conv8 , g_en_ema_8 = conv_block(conv7 , 512 , 8)
        g_ema.append(g_en_ema_8)

    with tf.variable_scope('Decoder_Stage'):
        up1 , g_de_ema_1 = up_block(conv8 , 512 , 1 , dropout = True)
        concat1 = tf.concat([conv7 , up1] , axis = -1)      
        up2 , g_de_ema_2 = up_block(concat1 , 512 , 2 , dropout = True)
        concat2 = tf.concat([conv6 , up2] , axis = -1)    
        up3 , g_de_ema_3 = up_block(concat2 , 512 , 3 , dropout = True)
        concat3 = tf.concat([conv5 , up3] , axis = -1)  
        up4 , g_de_ema_4 = up_block(concat3 , 512 , 4)
        concat4 = tf.concat([conv4 , up4] , axis = -1) 
        up5 , g_de_ema_5 = up_block(concat4 , 256 , 5)
        concat5 = tf.concat([conv3 , up5] , axis = -1)
        up6 , g_de_ema_6 = up_block(concat5 , 128 , 6)
        concat6 = tf.concat([conv2 , up6] , axis = -1)
        up7 , g_de_ema_7 = up_block(concat6 , 64 , 7)
        concat7 = tf.concat([conv1 , up7] , axis = -1)
        g_ema.extend([g_de_ema_1 , g_de_ema_2 , g_de_ema_3 , g_de_ema_4 , g_de_ema_5 , g_de_ema_6 , g_de_ema_7])
        
    with tf.variable_scope('Output_Stage'):
        fake_img = up_block(concat7 , 3 , 8 , stride = 1 , activation_func = tf.nn.tanh , batch_norm = False)

        
# Discriminator，相當於鑑定師
with tf.variable_scope('Discriminator'):
    fake_img_pair = tf.concat([blur_img , fake_img] , axis = -1)
    real_img_pair = tf.concat([blur_img , real_img] , axis = -1)
    d_fake_1 = conv_block(fake_img_pair , 64 , 1 , batch_norm = False)
    d_real_1 = conv_block(real_img_pair , 64 , 1 , batch_norm = False , reuse = True)
    d_fake_2 , d_ema_2_1 = conv_block(d_fake_1 , 128 , 2)
    d_real_2 , d_ema_2_2 = conv_block(d_real_1 , 128 , 2 , reuse = True)
    d_fake_3 , d_ema_3_1 = conv_block(d_fake_2 , 256 , 3)
    d_real_3 , d_ema_3_2 = conv_block(d_real_2 , 256 , 3 , reuse = True)
    d_fake_4 , d_ema_4_1 = conv_block(d_fake_3 , 512 , 4)
    d_real_4 , d_ema_4_2 = conv_block(d_real_3 , 512 , 4 , reuse = True)
    fake_output_d = conv_block(d_fake_4 , 1 , 5 , stride = 1 , activation_func = tf.nn.sigmoid , batch_norm = False)
    real_output_d = conv_block(d_real_4 , 1 , 5 , stride = 1 , activation_func = tf.nn.sigmoid , batch_norm = False , reuse = True)
    fake_output_d = tf.squeeze(fake_output_d , axis = -1)
    real_output_d = tf.squeeze(real_output_d , axis = -1)
    d_ema.extend([d_ema_2_1 , d_ema_2_2 , d_ema_3_1 , d_ema_3_2 , d_ema_4_1 , d_ema_4_2])


with tf.variable_scope('Discriminator_Loss'):
    # 鑑定師D會希望 fake_output_d 越小越好，等同於 -(1 - fake_output_d) 越小越好
    # 鑑定師D也會希望 real_output_d 越大越好，等同於 -real_output_d 越小越好
    # 所以 d_loss 會越來越小
    d_loss = tf.reduce_mean(-(tf.log(tf.clip_by_value(real_output_d , eps , tf.reduce_max(real_output_d))) +\
                            tf.log(tf.clip_by_value(1 - fake_output_d , eps , tf.reduce_max(1 - fake_output_d)))))


with tf.variable_scope('Generator_Loss'):
    l1_weight = 100
    # g_loss_l1負責捕捉影像低頻的特徵
    g_loss_l1 = l1_weight * tf.reduce_mean(tf.abs(fake_img - real_img))
    # 偽造家G會希望 fake_output_d 越大越好，等同於 (1 - fake_output_d) 越小越好
    # 所以g_loss_gan確實會越來越小
    # g_loss_gan負責捕捉影像高頻的特徵
    g_loss_gan = tf.reduce_mean(tf.log(tf.clip_by_value(1 - fake_output_d , eps , tf.reduce_max(1 - fake_output_d))))
    g_loss = g_loss_l1 + g_loss_gan
    
    
with tf.variable_scope('Optimizer'):
    g_ema_group , d_ema_group = tf.group(g_ema) , tf.group(d_ema)
    variable_Generator , variable_Discriminator = [] , []
    for v in tf.trainable_variables(): 
        if 'Generator' in v.name : variable_Generator.append(v)
        if 'Discriminator' in v.name : variable_Discriminator.append(v)
    lr_g , lr_d = 2e-4 , 2e-4
    train_Generator = tf.train.AdamOptimizer(lr_g , beta1 = 0.5).minimize(g_loss , var_list = variable_Generator)
    train_Discriminator = tf.train.AdamOptimizer(lr_d , beta1 = 0.5).minimize(d_loss , var_list = variable_Discriminator)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-3-97117c0722f6>:70: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

batch_size = 4
train_batch_generator = batch_generator(blur_train , real_train , batch_size)
epochs = 200
num_batch = math.ceil(len(blur_train) / batch_size)
for epoch_i in range(0 , epochs):
    d_loss_mean , g_loss_mean = 0 , 0
    for batch_i in range(0 , num_batch):
        x_train_bathch , y_train_bathch = next(train_batch_generator)
        x_train_bathch = (x_train_bathch - 127.5) / 127.5
        y_train_bathch = (y_train_bathch - 127.5) / 127.5
        _ , _ , d_loss_ = sess.run([train_Discriminator , d_ema_group , d_loss] ,
                                    feed_dict = {blur_img : x_train_bathch ,
                                                  real_img : y_train_bathch ,
                                                  on_train : True , 
                                                  keep_prob : 0.5})
        _ , _ , g_loss_ = sess.run([train_Generator , g_ema_group , g_loss] ,
                                    feed_dict = {blur_img : x_train_bathch ,
                                                  real_img : y_train_bathch ,
                                                  on_train : True , 
                                                  keep_prob : 0.5})

        d_loss_mean += d_loss_
        g_loss_mean += g_loss_

    print('=' * 30)
    print('epoch : {}'.format(epoch_i))
    print('Discriminator_loss_mean : {:.3f}'.format(d_loss_mean / num_batch))
    print('Generator_loss_mean : {:.3f}'.format(g_loss_mean / num_batch))
   
    if epoch_i % 2 == 0:
        img_pred_train = sess.run(fake_img ,
                    feed_dict = {blur_img : (blur_train[:2] - 127.5) / 127.5 ,
                                on_train : False , 
                                keep_prob : 1})

        img_pred_test = sess.run(fake_img ,
                    feed_dict = {blur_img : (blur_test[:2] - 127.5) / 127.5 ,
                                on_train : False , 
                                keep_prob : 1})
        
        img_pred_train = (img_pred_train + 1) * 127.5
        img_pred_test = (img_pred_test + 1) * 127.5
        np.save('img_pred_train_{}'.format(epoch_i) , img_pred_train[0] / 255)
        np.save('img_pred_test_{}'.format(epoch_i) , img_pred_test[0] / 255)
# Out:
# ==============================
# epoch : 0
# Discriminator_loss_mean : 1.365
# Generator_loss_mean : 9.361
# ==============================
# epoch : 1
# Discriminator_loss_mean : 0.554
# Generator_loss_mean : 5.519
# ==============================
# epoch : 2
# Discriminator_loss_mean : 0.010
# Generator_loss_mean : 5.271
# ==============================
# epoch : 3
# Discriminator_loss_mean : 0.486
# Generator_loss_mean : 4.569
# ==============================
# epoch : 4
# Discriminator_loss_mean : 1.308
# Generator_loss_mean : 4.064
# ==============================
# epoch : 5
# Discriminator_loss_mean : 1.105
# Generator_loss_mean : 4.104
# ==============================
# epoch : 6
# Discriminator_loss_mean : 0.450
# Generator_loss_mean : 4.099
# ==============================
# epoch : 7
# Discriminator_loss_mean : 0.007
# Generator_loss_mean : 4.067
# ==============================
# epoch : 8
# Discriminator_loss_mean : 0.004
# Generator_loss_mean : 3.990
# ==============================
# epoch : 9
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 3.969
# ==============================
# epoch : 10
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 3.810
# ==============================
# epoch : 11
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 3.704
# ==============================
# epoch : 12
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 3.600
# ==============================
# epoch : 13
# Discriminator_loss_mean : 0.236
# Generator_loss_mean : 3.417
# ==============================
# epoch : 14
# Discriminator_loss_mean : 1.103
# Generator_loss_mean : 3.211
# ==============================
# epoch : 15
# Discriminator_loss_mean : 0.968
# Generator_loss_mean : 3.519
# ==============================
# epoch : 16
# Discriminator_loss_mean : 0.414
# Generator_loss_mean : 3.420
# ==============================
# epoch : 17
# Discriminator_loss_mean : 0.074
# Generator_loss_mean : 3.314
# ==============================
# epoch : 18
# Discriminator_loss_mean : 0.848
# Generator_loss_mean : 3.140
# ==============================
# epoch : 19
# Discriminator_loss_mean : 1.148
# Generator_loss_mean : 3.163
# ==============================
# epoch : 20
# Discriminator_loss_mean : 0.538
# Generator_loss_mean : 3.242
# ==============================
# epoch : 21
# Discriminator_loss_mean : 0.032
# Generator_loss_mean : 3.220
# ==============================
# epoch : 22
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 3.130
# ==============================
# epoch : 23
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 3.022
# ==============================
# epoch : 24
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 3.081
# ==============================
# epoch : 25
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 3.111
# ==============================
# epoch : 26
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 3.063
# ==============================
# epoch : 27
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.974
# ==============================
# epoch : 28
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.893
# ==============================
# epoch : 29
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.854
# ==============================
# epoch : 30
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.808
# ==============================
# epoch : 31
# Discriminator_loss_mean : 0.977
# Generator_loss_mean : 2.281
# ==============================
# epoch : 32
# Discriminator_loss_mean : 1.335
# Generator_loss_mean : 2.309
# ==============================
# epoch : 33
# Discriminator_loss_mean : 1.306
# Generator_loss_mean : 2.390
# ==============================
# epoch : 34
# Discriminator_loss_mean : 0.846
# Generator_loss_mean : 3.138
# ==============================
# epoch : 35
# Discriminator_loss_mean : 0.005
# Generator_loss_mean : 3.110
# ==============================
# epoch : 36
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.901
# ==============================
# epoch : 37
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.763
# ==============================
# epoch : 38
# Discriminator_loss_mean : 0.942
# Generator_loss_mean : 2.474
# ==============================
# epoch : 39
# Discriminator_loss_mean : 0.800
# Generator_loss_mean : 2.916
# ==============================
# epoch : 40
# Discriminator_loss_mean : 0.029
# Generator_loss_mean : 3.065
# ==============================
# epoch : 41
# Discriminator_loss_mean : 0.735
# Generator_loss_mean : 2.718
# ==============================
# epoch : 42
# Discriminator_loss_mean : 0.213
# Generator_loss_mean : 2.838
# ==============================
# epoch : 43
# Discriminator_loss_mean : 0.005
# Generator_loss_mean : 3.028
# ==============================
# epoch : 44
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 3.284
# ==============================
# epoch : 45
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.895
# ==============================
# epoch : 46
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.784
# ==============================
# epoch : 47
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.812
# ==============================
# epoch : 48
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.708
# ==============================
# epoch : 49
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.656
# ==============================
# epoch : 50
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.698
# ==============================
# epoch : 51
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.628
# ==============================
# epoch : 52
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.591
# ==============================
# epoch : 53
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.584
# ==============================
# epoch : 54
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.511
# ==============================
# epoch : 55
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.576
# ==============================
# epoch : 56
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.665
# ==============================
# epoch : 57
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.531
# ==============================
# epoch : 58
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.473
# ==============================
# epoch : 59
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.923
# ==============================
# epoch : 60
# Discriminator_loss_mean : 0.690
# Generator_loss_mean : 2.194
# ==============================
# epoch : 61
# Discriminator_loss_mean : 1.340
# Generator_loss_mean : 1.982
# ==============================
# epoch : 62
# Discriminator_loss_mean : 0.904
# Generator_loss_mean : 2.457
# ==============================
# epoch : 63
# Discriminator_loss_mean : 0.006
# Generator_loss_mean : 2.595
# ==============================
# epoch : 64
# Discriminator_loss_mean : 1.191
# Generator_loss_mean : 2.237
# ==============================
# epoch : 65
# Discriminator_loss_mean : 1.327
# Generator_loss_mean : 2.255
# ==============================
# epoch : 66
# Discriminator_loss_mean : 1.160
# Generator_loss_mean : 2.529
# ==============================
# epoch : 67
# Discriminator_loss_mean : 0.298
# Generator_loss_mean : 2.763
# ==============================
# epoch : 68
# Discriminator_loss_mean : 0.005
# Generator_loss_mean : 2.500
# ==============================
# epoch : 69
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 2.423
# ==============================
# epoch : 70
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.445
# ==============================
# epoch : 71
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.368
# ==============================
# epoch : 72
# Discriminator_loss_mean : 0.151
# Generator_loss_mean : 2.367
# ==============================
# epoch : 73
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 2.407
# ==============================
# epoch : 74
# Discriminator_loss_mean : 0.661
# Generator_loss_mean : 2.309
# ==============================
# epoch : 75
# Discriminator_loss_mean : 1.140
# Generator_loss_mean : 2.501
# ==============================
# epoch : 76
# Discriminator_loss_mean : 0.147
# Generator_loss_mean : 2.450
# ==============================
# epoch : 77
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 2.385
# ==============================
# epoch : 78
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.333
# ==============================
# epoch : 79
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.327
# ==============================
# epoch : 80
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.331
# ==============================
# epoch : 81
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.297
# ==============================
# epoch : 82
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.292
# ==============================
# epoch : 83
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.285
# ==============================
# epoch : 84
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.256
# ==============================
# epoch : 85
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.245
# ==============================
# epoch : 86
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.663
# ==============================
# epoch : 87
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.688
# ==============================
# epoch : 88
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.414
# ==============================
# epoch : 89
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.510
# ==============================
# epoch : 90
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.379
# ==============================
# epoch : 91
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.315
# ==============================
# epoch : 92
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.312
# ==============================
# epoch : 93
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.343
# ==============================
# epoch : 94
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.381
# ==============================
# epoch : 95
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.308
# ==============================
# epoch : 96
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.244
# ==============================
# epoch : 97
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.229
# ==============================
# epoch : 98
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.232
# ==============================
# epoch : 99
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.215
# ==============================
# epoch : 100
# Discriminator_loss_mean : 0.821
# Generator_loss_mean : 1.836
# ==============================
# epoch : 101
# Discriminator_loss_mean : 1.276
# Generator_loss_mean : 1.866
# ==============================
# epoch : 102
# Discriminator_loss_mean : 1.315
# Generator_loss_mean : 2.063
# ==============================
# epoch : 103
# Discriminator_loss_mean : 1.197
# Generator_loss_mean : 2.021
# ==============================
# epoch : 104
# Discriminator_loss_mean : 0.636
# Generator_loss_mean : 2.458
# ==============================
# epoch : 105
# Discriminator_loss_mean : 0.008
# Generator_loss_mean : 2.257
# ==============================
# epoch : 106
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 2.230
# ==============================
# epoch : 107
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.231
# ==============================
# epoch : 108
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.326
# ==============================
# epoch : 109
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.394
# ==============================
# epoch : 110
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.304
# ==============================
# epoch : 111
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.234
# ==============================
# epoch : 112
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.182
# ==============================
# epoch : 113
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.175
# ==============================
# epoch : 114
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.155
# ==============================
# epoch : 115
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.423
# ==============================
# epoch : 116
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.204
# ==============================
# epoch : 117
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.267
# ==============================
# epoch : 118
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.262
# ==============================
# epoch : 119
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.368
# ==============================
# epoch : 120
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.295
# ==============================
# epoch : 121
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.228
# ==============================
# epoch : 122
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.197
# ==============================
# epoch : 123
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.163
# ==============================
# epoch : 124
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.201
# ==============================
# epoch : 125
# Discriminator_loss_mean : 1.072
# Generator_loss_mean : 1.620
# ==============================
# epoch : 126
# Discriminator_loss_mean : 1.332
# Generator_loss_mean : 1.619
# ==============================
# epoch : 127
# Discriminator_loss_mean : 1.302
# Generator_loss_mean : 1.973
# ==============================
# epoch : 128
# Discriminator_loss_mean : 0.679
# Generator_loss_mean : 3.535
# ==============================
# epoch : 129
# Discriminator_loss_mean : 0.004
# Generator_loss_mean : 3.128
# ==============================
# epoch : 130
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.774
# ==============================
# epoch : 131
# Discriminator_loss_mean : 0.099
# Generator_loss_mean : 2.611
# ==============================
# epoch : 132
# Discriminator_loss_mean : 0.127
# Generator_loss_mean : 2.601
# ==============================
# epoch : 133
# Discriminator_loss_mean : 0.116
# Generator_loss_mean : 2.425
# ==============================
# epoch : 134
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 2.472
# ==============================
# epoch : 135
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.345
# ==============================
# epoch : 136
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.298
# ==============================
# epoch : 137
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.454
# ==============================
# epoch : 138
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.328
# ==============================
# epoch : 139
# Discriminator_loss_mean : 0.670
# Generator_loss_mean : 2.128
# ==============================
# epoch : 140
# Discriminator_loss_mean : 1.037
# Generator_loss_mean : 2.460
# ==============================
# epoch : 141
# Discriminator_loss_mean : 0.479
# Generator_loss_mean : 2.527
# ==============================
# epoch : 142
# Discriminator_loss_mean : 0.004
# Generator_loss_mean : 2.332
# ==============================
# epoch : 143
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.291
# ==============================
# epoch : 144
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.287
# ==============================
# epoch : 145
# Discriminator_loss_mean : 0.017
# Generator_loss_mean : 2.314
# ==============================
# epoch : 146
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.232
# ==============================
# epoch : 147
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.388
# ==============================
# epoch : 148
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.290
# ==============================
# epoch : 149
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.256
# ==============================
# epoch : 150
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.220
# ==============================
# epoch : 151
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.332
# ==============================
# epoch : 152
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.293
# ==============================
# epoch : 153
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.229
# ==============================
# epoch : 154
# Discriminator_loss_mean : 0.336
# Generator_loss_mean : 2.127
# ==============================
# epoch : 155
# Discriminator_loss_mean : 0.048
# Generator_loss_mean : 2.481
# ==============================
# epoch : 156
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.293
# ==============================
# epoch : 157
# Discriminator_loss_mean : 0.143
# Generator_loss_mean : 2.297
# ==============================
# epoch : 158
# Discriminator_loss_mean : 1.287
# Generator_loss_mean : 1.999
# ==============================
# epoch : 159
# Discriminator_loss_mean : 1.292
# Generator_loss_mean : 2.106
# ==============================
# epoch : 160
# Discriminator_loss_mean : 1.247
# Generator_loss_mean : 2.173
# ==============================
# epoch : 161
# Discriminator_loss_mean : 1.232
# Generator_loss_mean : 2.150
# ==============================
# epoch : 162
# Discriminator_loss_mean : 0.497
# Generator_loss_mean : 2.464
# ==============================
# epoch : 163
# Discriminator_loss_mean : 0.004
# Generator_loss_mean : 2.302
# ==============================
# epoch : 164
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.271
# ==============================
# epoch : 165
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.237
# ==============================
# epoch : 166
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.206
# ==============================
# epoch : 167
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.187
# ==============================
# epoch : 168
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.967
# ==============================
# epoch : 169
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.480
# ==============================
# epoch : 170
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.282
# ==============================
# epoch : 171
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.196
# ==============================
# epoch : 172
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.273
# ==============================
# epoch : 173
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.180
# ==============================
# epoch : 174
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.343
# ==============================
# epoch : 175
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.179
# ==============================
# epoch : 176
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.161
# ==============================
# epoch : 177
# Discriminator_loss_mean : 0.252
# Generator_loss_mean : 2.033
# ==============================
# epoch : 178
# Discriminator_loss_mean : 1.044
# Generator_loss_mean : 2.237
# ==============================
# epoch : 179
# Discriminator_loss_mean : 1.207
# Generator_loss_mean : 2.307
# ==============================
# epoch : 180
# Discriminator_loss_mean : 0.062
# Generator_loss_mean : 2.838
# ==============================
# epoch : 181
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 2.295
# ==============================
# epoch : 182
# Discriminator_loss_mean : 0.058
# Generator_loss_mean : 2.235
# ==============================
# epoch : 183
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 2.219
# ==============================
# epoch : 184
# Discriminator_loss_mean : 0.745
# Generator_loss_mean : 2.165
# ==============================
# epoch : 185
# Discriminator_loss_mean : 1.023
# Generator_loss_mean : 2.242
# ==============================
# epoch : 186
# Discriminator_loss_mean : 0.195
# Generator_loss_mean : 2.166
# ==============================
# epoch : 187
# Discriminator_loss_mean : 1.231
# Generator_loss_mean : 2.196
# ==============================
# epoch : 188
# Discriminator_loss_mean : 0.996
# Generator_loss_mean : 2.326
# ==============================
# epoch : 189
# Discriminator_loss_mean : 0.010
# Generator_loss_mean : 2.215
# ==============================
# epoch : 190
# Discriminator_loss_mean : 0.006
# Generator_loss_mean : 2.127
# ==============================
# epoch : 191
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.116
# ==============================
# epoch : 192
# Discriminator_loss_mean : 0.098
# Generator_loss_mean : 2.124
# ==============================
# epoch : 193
# Discriminator_loss_mean : 0.270
# Generator_loss_mean : 2.208
# ==============================
# epoch : 194
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 2.127
# ==============================
# epoch : 195
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.120
# ==============================
# epoch : 196
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.107
# ==============================
# epoch : 197
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 2.232
# ==============================
# epoch : 198
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 2.167
# ==============================
# epoch : 199
# Discriminator_loss_mean : 0.070
# Generator_loss_mean : 2.077

# %%
for img_idx in [0] + list(range(6 , 20)):
    img_pred =  sess.run(fake_img , 
                feed_dict = {blur_img : np.expand_dims((blur_test[img_idx] - 127.5) / 127.5 , axis = 0)  ,
                        on_train : False , 
                        keep_prob : 1})

    fig , ax = plt.subplots(1 , 3 , figsize = (8 , 8))

    ax[0].imshow(real_test[img_idx] / 255.)
    ax[0].set_xticks([])
    ax[0].set_yticks([])
    ax[0].set_title('Original Image')

    ax[1].imshow(blur_test[img_idx] / 255.)
    ax[1].set_xticks([])
    ax[1].set_yticks([])
    ax[1].set_title('Blur Image')

    ax[2].imshow((img_pred[0] + 1) * 127.5 / 255)
    ax[2].set_xticks([])
    ax[2].set_yticks([])
    ax[2].set_title('Predicted Image')

# %%
saver = tf.train.Saver()
saver.save(sess , 'blur_model/blur_model')
print('Model Trained and Saved')
# Out:
# Model Trained and Saved
