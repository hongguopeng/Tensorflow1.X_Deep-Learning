# %% [markdown]
# ### 請解壓縮data.rar，取得本程式之數據
# ### 訓練資料來自 : http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html

# %%
from google.colab import drive
# %tensorflow_version 1.x
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import scipy.misc as sc 
import math
import cv2
import os
import matplotlib.pyplot as plt

drive.mount('/content/gdrive')
path = os.path.join(os.getcwd() , 'gdrive' , 'My Drive' , 'pix2pix_blur_gan')
os.chdir(path)
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# Mounted at /content/gdrive

# %%
# 讀取訓練與測試資料
img_resize = np.load('images_resize.npy')
img_blur = np.load('images_blur.npy')
real_train = img_resize[:900]
blur_train = img_blur[:900]
real_test = img_resize[900:]
blur_test = img_blur[900:]
del img_resize , img_blur

# %%
def batch_norm_layer_part1(inputs , on_train , convolution):
    # the dimension you wanna normalize, here [0] for batch
    # for image, you wanna do [0 , 1 , 2] for [batch , height , width] but not channel
    if convolution:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0 , 1 , 2] , name = 'mean_var')
    else:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0] , name = 'mean_var')

    ema = tf.train.ExponentialMovingAverage(decay = 0.75)
    ema_apply_op = ema.apply([fc_mean , fc_var])
    mean = tf.cond(on_train , lambda : fc_mean , lambda : ema.average(fc_mean))
    var = tf.cond(on_train , lambda : fc_var , lambda : ema.average(fc_var))
    return mean , var , ema_apply_op

def batch_norm_layer_part2(inputs , mean , var):
    scale = tf.get_variable(shape = inputs.shape[-1].value , initializer = tf.random_normal_initializer(1 , 0.02) , name = 'scale')
    shift = tf.get_variable(shape = inputs.shape[-1].value , initializer = tf.zeros_initializer , name = 'shift')
    temp = (inputs - mean) / tf.sqrt(var + 1e-8)
    outputs = tf.multiply(temp , scale) + shift
    return outputs


def conv_block(inputs , n_filter , layer , kernel_size = 4 , stride = 2 , padding = 'same' ,
               activation_func = tf.nn.leaky_relu , batch_norm = True , reuse = False):
    with tf.variable_scope('Conv{}'.format(layer)) as scope:
        if reuse: tf.get_variable_scope().reuse_variables()
        conv = tf.contrib.layers.conv2d(inputs , n_filter , [kernel_size , kernel_size] ,
                                        stride = stride , padding = padding , activation_fn = None ,
                                        weights_initializer = tf.contrib.layers.xavier_initializer_conv2d(uniform = False))
    if activation_func is not None:
        conv = activation_func(conv)    
    
    if batch_norm:
        with tf.variable_scope('Conv{}_compute_mean_var'.format(layer)):
            conv_mean , conv_var , conv_ema = batch_norm_layer_part1(conv , on_train , True)
        with tf.variable_scope(scope):
            conv = batch_norm_layer_part2(conv , conv_mean , conv_var)

    if batch_norm: 
        return conv , conv_ema
    else:
        return conv


def up_block(inputs , n_filter , layer , kernel_size = 4 , stride = 1 , padding = 'same' ,
             activation_func = tf.nn.relu , batch_norm = True , dropout = False , reuse = False):
    with tf.variable_scope('Up{}'.format(layer)) as scope:
        if reuse: tf.get_variable_scope().reuse_variables()
        up = tf.keras.layers.UpSampling2D(size = [2, 2])(inputs)
        up = tf.contrib.layers.conv2d(up , n_filter , [kernel_size , kernel_size] ,  
                                      stride = stride , padding = padding , activation_fn = None ,
                                      weights_initializer = tf.contrib.layers.xavier_initializer_conv2d(uniform = False))

    if activation_func is not None:
        up = activation_func(up)  

    if batch_norm:
        with tf.variable_scope('Up{}_compute_mean_var'.format(layer)):
            up_mean , up_var , up_ema = batch_norm_layer_part1(up , on_train , True)
        with tf.variable_scope(scope):
            up = batch_norm_layer_part2(up , up_mean , up_var)

    if batch_norm:
        if dropout: up = tf.nn.dropout(up , keep_prob)         
        return up , up_ema
    else:
        return up


def batch_generator(X , y , batch_size):
    size = X.shape[0]
    X_copy = X.copy()
    y_copy = y.copy()
    indices = np.arange(size)
    np.random.shuffle(indices)
    X_copy = X_copy[indices]
    y_copy = y_copy[indices]
    i = 0
    while True:
        if i + batch_size <= size:
            yield X_copy[i : i + batch_size] , y_copy[i : i + batch_size]
            i += batch_size
        else:
            i = 0
            indices = np.arange(size)
            np.random.shuffle(indices)
            X_copy = X_copy[indices]
            y_copy = y_copy[indices]

# %%
eps = 1e-8
g_ema , d_ema = [] , []
blur_img = tf.placeholder(tf.float32 , [None , 256 , 256 , 3] , name = 'blur_img')
real_img = tf.placeholder(tf.float32 , [None , 256 , 256 , 3] , name = 'real_img')
keep_prob = tf.placeholder(tf.float32 , name = 'keep_prob')
on_train = tf.placeholder(tf.bool , name = 'on_train')

# %%
# Generator採用的是UNET的架構
# Generator，相當於偽造家
with tf.variable_scope('Generator'):
    with tf.variable_scope('Encoder_Stage'):
        conv1 = conv_block(blur_img , 64 , 1 , batch_norm = False)
        conv2 , g_en_ema_2 = conv_block(conv1 , 128 , 2)
        conv3 , g_en_ema_3 = conv_block(conv2 , 256 , 3)
        conv4 , g_en_ema_4 = conv_block(conv3 , 512 , 4)
        conv5 , g_en_ema_5 = conv_block(conv4 , 512 , 5)
        conv6 , g_en_ema_6 = conv_block(conv5 , 512 , 6)
        conv7 , g_en_ema_7 = conv_block(conv6 , 512 , 7)
        g_ema.extend([g_en_ema_2 , g_en_ema_3 , g_en_ema_4 , g_en_ema_5 , g_en_ema_6 , g_en_ema_7])

    with tf.variable_scope('Middle_Stage'):    
        conv8 , g_en_ema_8 = conv_block(conv7 , 512 , 8)
        g_ema.append(g_en_ema_8)

    with tf.variable_scope('Decoder_Stage'):
        up1 , g_de_ema_1 = up_block(conv8 , 512 , 1 , dropout = True)
        up2 , g_de_ema_2 = up_block(up1 , 512 , 2 , dropout = True)
        up3 , g_de_ema_3 = up_block(up2 , 512 , 3 , dropout = True)
        up4 , g_de_ema_4 = up_block(up3 , 512 , 4)
        up5 , g_de_ema_5 = up_block(up4 , 256 , 5)
        up6 , g_de_ema_6 = up_block(up5 , 128 , 6)
        up7 , g_de_ema_7 = up_block(up6 , 64 , 7)
        g_ema.extend([g_de_ema_1 , g_de_ema_2 , g_de_ema_3 , g_de_ema_4 , g_de_ema_5 , g_de_ema_6 , g_de_ema_7])
        
    with tf.variable_scope('Output_Stage'):
        fake_img = up_block(up7 , 3 , 8 , stride = 1 , activation_func = tf.nn.tanh , batch_norm = False)

        
# Discriminator，相當於鑑定師
with tf.variable_scope('Discriminator'):
    fake_img_pair = tf.concat([blur_img , fake_img] , axis = -1)
    real_img_pair = tf.concat([blur_img , real_img] , axis = -1)
    d_fake_1 = conv_block(fake_img_pair , 64 , 1 , batch_norm = False)
    d_real_1 = conv_block(real_img_pair , 64 , 1 , batch_norm = False , reuse = True)
    d_fake_2 , d_ema_2_1 = conv_block(d_fake_1 , 128 , 2)
    d_real_2 , d_ema_2_2 = conv_block(d_real_1 , 128 , 2 , reuse = True)
    d_fake_3 , d_ema_3_1 = conv_block(d_fake_2 , 256 , 3)
    d_real_3 , d_ema_3_2 = conv_block(d_real_2 , 256 , 3 , reuse = True)
    d_fake_4 , d_ema_4_1 = conv_block(d_fake_3 , 512 , 4)
    d_real_4 , d_ema_4_2 = conv_block(d_real_3 , 512 , 4 , reuse = True)
    fake_output_d = conv_block(d_fake_4 , 1 , 5 , stride = 1 , activation_func = tf.nn.sigmoid , batch_norm = False)
    real_output_d = conv_block(d_real_4 , 1 , 5 , stride = 1 , activation_func = tf.nn.sigmoid , batch_norm = False , reuse = True)
    fake_output_d = tf.squeeze(fake_output_d , axis = -1)
    real_output_d = tf.squeeze(real_output_d , axis = -1)
    d_ema.extend([d_ema_2_1 , d_ema_2_2 , d_ema_3_1 , d_ema_3_2 , d_ema_4_1 , d_ema_4_2])


with tf.variable_scope('Discriminator_Loss'):
    # 鑑定師D會希望 fake_output_d 越小越好，等同於 -(1 - fake_output_d) 越小越好
    # 鑑定師D也會希望 real_output_d 越大越好，等同於 -real_output_d 越小越好
    # 所以 d_loss 會越來越小
    d_loss = tf.reduce_mean(-(tf.log(tf.clip_by_value(real_output_d , eps , tf.reduce_max(real_output_d))) +\
                            tf.log(tf.clip_by_value(1 - fake_output_d , eps , tf.reduce_max(1 - fake_output_d)))))


with tf.variable_scope('Generator_Loss'):
    l1_weight = 100
    # g_loss_l1負責捕捉影像低頻的特徵
    g_loss_l1 = l1_weight * tf.reduce_mean(tf.abs(fake_img - real_img))
    # 偽造家G會希望 fake_output_d 越大越好，等同於 (1 - fake_output_d) 越小越好
    # 所以g_loss_gan確實會越來越小
    # g_loss_gan負責捕捉影像高頻的特徵
    g_loss_gan = tf.reduce_mean(tf.log(tf.clip_by_value(1 - fake_output_d , eps , tf.reduce_max(1 - fake_output_d))))
    g_loss = g_loss_l1 + g_loss_gan
    
    
with tf.variable_scope('Optimizer'):
    g_ema_group , d_ema_group = tf.group(g_ema) , tf.group(d_ema)
    variable_Generator , variable_Discriminator = [] , []
    for v in tf.trainable_variables(): 
        if 'Generator' in v.name : variable_Generator.append(v)
        if 'Discriminator' in v.name : variable_Discriminator.append(v)
    lr_g , lr_d = 2e-4 , 2e-4
    train_Generator = tf.train.AdamOptimizer(lr_g , beta1 = 0.5).minimize(g_loss , var_list = variable_Generator)
    train_Discriminator = tf.train.AdamOptimizer(lr_d , beta1 = 0.5).minimize(d_loss , var_list = variable_Discriminator)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-3-42494695d110>:64: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

batch_size = 4
train_batch_generator = batch_generator(blur_train , real_train , batch_size)
epochs = 200
num_batch = math.ceil(len(blur_train) / batch_size)
for epoch_i in range(0 , epochs):
    d_loss_mean , g_loss_mean = 0 , 0
    for batch_i in range(0 , num_batch):
        x_train_bathch , y_train_bathch = next(train_batch_generator)
        x_train_bathch = (x_train_bathch - 127.5) / 127.5
        y_train_bathch = (y_train_bathch - 127.5) / 127.5
        _ , _ , d_loss_ = sess.run([train_Discriminator , d_ema_group , d_loss] ,
                                    feed_dict = {blur_img : x_train_bathch ,
                                                  real_img : y_train_bathch ,
                                                  on_train : True , 
                                                  keep_prob : 0.5})
        _ , _ , g_loss_ = sess.run([train_Generator , g_ema_group , g_loss] ,
                                    feed_dict = {blur_img : x_train_bathch ,
                                                  real_img : y_train_bathch ,
                                                  on_train : True , 
                                                  keep_prob : 0.5})

        d_loss_mean += d_loss_
        g_loss_mean += g_loss_

    print('=' * 30)
    print('epoch : {}'.format(epoch_i))
    print('Discriminator_loss_mean : {:.3f}'.format(d_loss_mean / num_batch))
    print('Generator_loss_mean : {:.3f}'.format(g_loss_mean / num_batch))
   
    if epoch_i % 2 == 0:
        img_pred_train = sess.run(fake_img ,
                    feed_dict = {blur_img : (blur_train[:2] - 127.5) / 127.5 ,
                                on_train : False , 
                                keep_prob : 1})

        img_pred_test = sess.run(fake_img ,
                    feed_dict = {blur_img : (blur_test[:2] - 127.5) / 127.5 ,
                                on_train : False , 
                                keep_prob : 1})
        
        img_pred_train = (img_pred_train + 1) * 127.5
        img_pred_test = (img_pred_test + 1) * 127.5
        np.save('img_pred_train_{}'.format(epoch_i) , img_pred_train[0] / 255)
        np.save('img_pred_test_{}'.format(epoch_i) , img_pred_test[0] / 255)
# Out:
# ==============================
# epoch : 0
# Discriminator_loss_mean : 0.288
# Generator_loss_mean : 42.298
# ==============================
# epoch : 1
# Discriminator_loss_mean : 0.004
# Generator_loss_mean : 37.659
# ==============================
# epoch : 2
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 36.379
# ==============================
# epoch : 3
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 35.643
# ==============================
# epoch : 4
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 34.091
# ==============================
# epoch : 5
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 34.237
# ==============================
# epoch : 6
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 33.320
# ==============================
# epoch : 7
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 33.121
# ==============================
# epoch : 8
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 32.559
# ==============================
# epoch : 9
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 32.236
# ==============================
# epoch : 10
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 32.333
# ==============================
# epoch : 11
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 31.699
# ==============================
# epoch : 12
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 31.397
# ==============================
# epoch : 13
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 31.202
# ==============================
# epoch : 14
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 31.094
# ==============================
# epoch : 15
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.447
# ==============================
# epoch : 16
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 31.225
# ==============================
# epoch : 17
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.978
# ==============================
# epoch : 18
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.941
# ==============================
# epoch : 19
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.024
# ==============================
# epoch : 20
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.158
# ==============================
# epoch : 21
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.912
# ==============================
# epoch : 22
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.597
# ==============================
# epoch : 23
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.671
# ==============================
# epoch : 24
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.561
# ==============================
# epoch : 25
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.364
# ==============================
# epoch : 26
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.022
# ==============================
# epoch : 27
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.156
# ==============================
# epoch : 28
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.519
# ==============================
# epoch : 29
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.519
# ==============================
# epoch : 30
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.315
# ==============================
# epoch : 31
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.419
# ==============================
# epoch : 32
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.882
# ==============================
# epoch : 33
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.136
# ==============================
# epoch : 34
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.543
# ==============================
# epoch : 35
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.234
# ==============================
# epoch : 36
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.715
# ==============================
# epoch : 37
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.318
# ==============================
# epoch : 38
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.790
# ==============================
# epoch : 39
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.734
# ==============================
# epoch : 40
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.665
# ==============================
# epoch : 41
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.665
# ==============================
# epoch : 42
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.610
# ==============================
# epoch : 43
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.317
# ==============================
# epoch : 44
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.173
# ==============================
# epoch : 45
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.032
# ==============================
# epoch : 46
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.254
# ==============================
# epoch : 47
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.226
# ==============================
# epoch : 48
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.427
# ==============================
# epoch : 49
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.915
# ==============================
# epoch : 50
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.888
# ==============================
# epoch : 51
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.783
# ==============================
# epoch : 52
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.725
# ==============================
# epoch : 53
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.795
# ==============================
# epoch : 54
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.486
# ==============================
# epoch : 55
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.619
# ==============================
# epoch : 56
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.355
# ==============================
# epoch : 57
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.436
# ==============================
# epoch : 58
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.354
# ==============================
# epoch : 59
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.335
# ==============================
# epoch : 60
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.363
# ==============================
# epoch : 61
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.453
# ==============================
# epoch : 62
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.046
# ==============================
# epoch : 63
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.070
# ==============================
# epoch : 64
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.975
# ==============================
# epoch : 65
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.534
# ==============================
# epoch : 66
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.263
# ==============================
# epoch : 67
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.003
# ==============================
# epoch : 68
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.175
# ==============================
# epoch : 69
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.793
# ==============================
# epoch : 70
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.726
# ==============================
# epoch : 71
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.746
# ==============================
# epoch : 72
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.401
# ==============================
# epoch : 73
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.574
# ==============================
# epoch : 74
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.569
# ==============================
# epoch : 75
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.282
# ==============================
# epoch : 76
# Discriminator_loss_mean : 0.833
# Generator_loss_mean : 24.770
# ==============================
# epoch : 77
# Discriminator_loss_mean : 0.045
# Generator_loss_mean : 25.518
# ==============================
# epoch : 78
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 25.434
# ==============================
# epoch : 79
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 26.052
# ==============================
# epoch : 80
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 25.546
# ==============================
# epoch : 81
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.284
# ==============================
# epoch : 82
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.921
# ==============================
# epoch : 83
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.929
# ==============================
# epoch : 84
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.144
# ==============================
# epoch : 85
# Discriminator_loss_mean : 0.065
# Generator_loss_mean : 25.041
# ==============================
# epoch : 86
# Discriminator_loss_mean : 0.207
# Generator_loss_mean : 25.057
# ==============================
# epoch : 87
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 24.933
# ==============================
# epoch : 88
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 25.138
# ==============================
# epoch : 89
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.229
# ==============================
# epoch : 90
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.993
# ==============================
# epoch : 91
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.763
# ==============================
# epoch : 92
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.665
# ==============================
# epoch : 93
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.607
# ==============================
# epoch : 94
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.520
# ==============================
# epoch : 95
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.455
# ==============================
# epoch : 96
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.473
# ==============================
# epoch : 97
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.641
# ==============================
# epoch : 98
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.487
# ==============================
# epoch : 99
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.447
# ==============================
# epoch : 100
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.338
# ==============================
# epoch : 101
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.260
# ==============================
# epoch : 102
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.303
# ==============================
# epoch : 103
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.401
# ==============================
# epoch : 104
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.294
# ==============================
# epoch : 105
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.280
# ==============================
# epoch : 106
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.326
# ==============================
# epoch : 107
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.239
# ==============================
# epoch : 108
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.976
# ==============================
# epoch : 109
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.448
# ==============================
# epoch : 110
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.433
# ==============================
# epoch : 111
# Discriminator_loss_mean : 0.273
# Generator_loss_mean : 23.960
# ==============================
# epoch : 112
# Discriminator_loss_mean : 0.003
# Generator_loss_mean : 24.004
# ==============================
# epoch : 113
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 23.783
# ==============================
# epoch : 114
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 23.798
# ==============================
# epoch : 115
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.852
# ==============================
# epoch : 116
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.849
# ==============================
# epoch : 117
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.637
# ==============================
# epoch : 118
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.530
# ==============================
# epoch : 119
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.672
# ==============================
# epoch : 120
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.860
# ==============================
# epoch : 121
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.436
# ==============================
# epoch : 122
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.648
# ==============================
# epoch : 123
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.770
# ==============================
# epoch : 124
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.482
# ==============================
# epoch : 125
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.410
# ==============================
# epoch : 126
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.508
# ==============================
# epoch : 127
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.417
# ==============================
# epoch : 128
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.437
# ==============================
# epoch : 129
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.419
# ==============================
# epoch : 130
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.317
# ==============================
# epoch : 131
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.228
# ==============================
# epoch : 132
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.254
# ==============================
# epoch : 133
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.230
# ==============================
# epoch : 134
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.251
# ==============================
# epoch : 135
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.396
# ==============================
# epoch : 136
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.013
# ==============================
# epoch : 137
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.049
# ==============================
# epoch : 138
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.414
# ==============================
# epoch : 139
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.240
# ==============================
# epoch : 140
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.852
# ==============================
# epoch : 141
# Discriminator_loss_mean : 0.198
# Generator_loss_mean : 22.921
# ==============================
# epoch : 142
# Discriminator_loss_mean : 0.048
# Generator_loss_mean : 22.852
# ==============================
# epoch : 143
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 23.025
# ==============================
# epoch : 144
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 22.985
# ==============================
# epoch : 145
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.929
# ==============================
# epoch : 146
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.851
# ==============================
# epoch : 147
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.731
# ==============================
# epoch : 148
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.627
# ==============================
# epoch : 149
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.756
# ==============================
# epoch : 150
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.727
# ==============================
# epoch : 151
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.776
# ==============================
# epoch : 152
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.927
# ==============================
# epoch : 153
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.661
# ==============================
# epoch : 154
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.643
# ==============================
# epoch : 155
# Discriminator_loss_mean : 0.206
# Generator_loss_mean : 22.517
# ==============================
# epoch : 156
# Discriminator_loss_mean : 0.004
# Generator_loss_mean : 22.541
# ==============================
# epoch : 157
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 22.540
# ==============================
# epoch : 158
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.260
# ==============================
# epoch : 159
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.343
# ==============================
# epoch : 160
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.164
# ==============================
# epoch : 161
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.222
# ==============================
# epoch : 162
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.604
# ==============================
# epoch : 163
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.383
# ==============================
# epoch : 164
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.101
# ==============================
# epoch : 165
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.299
# ==============================
# epoch : 166
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.168
# ==============================
# epoch : 167
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.373
# ==============================
# epoch : 168
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.359
# ==============================
# epoch : 169
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.241
# ==============================
# epoch : 170
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.150
# ==============================
# epoch : 171
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.023
# ==============================
# epoch : 172
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.105
# ==============================
# epoch : 173
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.189
# ==============================
# epoch : 174
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.947
# ==============================
# epoch : 175
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.108
# ==============================
# epoch : 176
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.832
# ==============================
# epoch : 177
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.908
# ==============================
# epoch : 178
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.994
# ==============================
# epoch : 179
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.993
# ==============================
# epoch : 180
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.811
# ==============================
# epoch : 181
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.844
# ==============================
# epoch : 182
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.731
# ==============================
# epoch : 183
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.635
# ==============================
# epoch : 184
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.541
# ==============================
# epoch : 185
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.730
# ==============================
# epoch : 186
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.857
# ==============================
# epoch : 187
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.846
# ==============================
# epoch : 188
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.722
# ==============================
# epoch : 189
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.591
# ==============================
# epoch : 190
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.715
# ==============================
# epoch : 191
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.643
# ==============================
# epoch : 192
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.871
# ==============================
# epoch : 193
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.599
# ==============================
# epoch : 194
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.513
# ==============================
# epoch : 195
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.543
# ==============================
# epoch : 196
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.506
# ==============================
# epoch : 197
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.425
# ==============================
# epoch : 198
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.381
# ==============================
# epoch : 199
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.560

# %%
for img_idx in [0] + list(range(6 , 20)):
    img_pred =  sess.run(fake_img , 
                feed_dict = {blur_img : np.expand_dims((blur_test[img_idx] - 127.5) / 127.5 , axis = 0)  ,
                        on_train : False , 
                        keep_prob : 1})

    fig , ax = plt.subplots(1 , 3 , figsize = (8 , 8))

    ax[0].imshow(real_test[img_idx] / 255.)
    ax[0].set_xticks([])
    ax[0].set_yticks([])
    ax[0].set_title('Original Image')

    ax[1].imshow(blur_test[img_idx] / 255.)
    ax[1].set_xticks([])
    ax[1].set_yticks([])
    ax[1].set_title('Blur Image')

    ax[2].imshow((img_pred[0] + 1) * 127.5 / 255)
    ax[2].set_xticks([])
    ax[2].set_yticks([])
    ax[2].set_title('Predicted Image')

# %%
saver = tf.train.Saver()
saver.save(sess , 'blur_model/blur_model')
print('Model Trained and Saved')
# Out:
# Model Trained and Saved
