# %%
from google.colab import drive
# %tensorflow_version 1.x
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import scipy.misc as sc 
import math
import cv2
import os
import matplotlib.pyplot as plt

drive.mount('/content/gdrive')
path = os.path.join(os.getcwd() , 'gdrive' , 'My Drive' , 'pix2pix_mosaic_gan')
os.chdir(path)
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# Mounted at /content/gdrive

# %%
img_resize = np.load('images_resize.npy')
img_mosaic = np.load('images_mosaic.npy')
real_train = img_resize[:900]
mosaic_train = img_mosaic[:900]
real_test = img_resize[900:]
mosaic_test = img_mosaic[900:]
del img_resize , img_mosaic

# %%
def batch_norm_layer_part1(inputs , on_train , convolution):
    # the dimension you wanna normalize, here [0] for batch
    # for image, you wanna do [0 , 1 , 2] for [batch , height , width] but not channel
    if convolution:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0 , 1 , 2] , name = 'mean_var')
    else:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0] , name = 'mean_var')

    ema = tf.train.ExponentialMovingAverage(decay = 0.75)
    ema_apply_op = ema.apply([fc_mean , fc_var])
    mean = tf.cond(on_train , lambda : fc_mean , lambda : ema.average(fc_mean))
    var = tf.cond(on_train , lambda : fc_var , lambda : ema.average(fc_var))
    return mean , var , ema_apply_op

def batch_norm_layer_part2(inputs , mean , var):
    scale = tf.get_variable(shape = inputs.shape[-1].value , initializer = tf.random_normal_initializer(1 , 0.02) , name = 'scale')
    shift = tf.get_variable(shape = inputs.shape[-1].value , initializer = tf.zeros_initializer , name = 'shift')
    temp = (inputs - mean) / tf.sqrt(var + 1e-8)
    outputs = tf.multiply(temp , scale) + shift
    return outputs


def conv_block(inputs , n_filter , layer , kernel_size = 4 , stride = 2 , padding = 'same' ,
               activation_func = tf.nn.leaky_relu , batch_norm = True , reuse = False):
    # if activation_func is not None:
    #     inputs = activation_func(inputs)
    
    with tf.variable_scope('Conv{}'.format(layer)) as scope:
        if reuse: tf.get_variable_scope().reuse_variables()
        conv = tf.contrib.layers.conv2d(inputs , n_filter , [kernel_size , kernel_size] ,
                                        stride = stride , padding = padding , activation_fn = None ,
                                        weights_initializer = tf.contrib.layers.xavier_initializer_conv2d(uniform = False))
    if activation_func is not None:
        conv = activation_func(conv)    
    
    if batch_norm:
        with tf.variable_scope('Conv{}_compute_mean_var'.format(layer)):
            conv_mean , conv_var , conv_ema = batch_norm_layer_part1(conv , on_train , True)
        with tf.variable_scope(scope):
            conv = batch_norm_layer_part2(conv , conv_mean , conv_var)

    if batch_norm: 
        return conv , conv_ema
    else:
        return conv


def up_block(inputs , n_filter , layer , kernel_size = 4 , stride = 1 , padding = 'same' ,
             activation_func = tf.nn.relu , batch_norm = True , dropout = False , reuse = False):
    # if activation_func is not None:
    #     inputs = activation_func(inputs)
    
    with tf.variable_scope('Up{}'.format(layer)) as scope:
        if reuse: tf.get_variable_scope().reuse_variables()
        up = tf.keras.layers.UpSampling2D(size = [2, 2])(inputs)
        up = tf.contrib.layers.conv2d(up , n_filter , [kernel_size , kernel_size] ,  
                                      stride = stride , padding = padding , activation_fn = None ,
                                      weights_initializer = tf.contrib.layers.xavier_initializer_conv2d(uniform = False))

    if activation_func is not None:
        up = activation_func(up)  

    if batch_norm:
        with tf.variable_scope('Up{}_compute_mean_var'.format(layer)):
            up_mean , up_var , up_ema = batch_norm_layer_part1(up , on_train , True)
        with tf.variable_scope(scope):
            up = batch_norm_layer_part2(up , up_mean , up_var)

    if batch_norm:
        if dropout: up = tf.nn.dropout(up , keep_prob)         
        return up , up_ema
    else:
        return up


def batch_generator(X , y , batch_size):
    size = X.shape[0]
    X_copy = X.copy()
    y_copy = y.copy()
    indices = np.arange(size)
    np.random.shuffle(indices)
    X_copy = X_copy[indices]
    y_copy = y_copy[indices]
    i = 0
    while True:
        if i + batch_size <= size:
            yield X_copy[i : i + batch_size] , y_copy[i : i + batch_size]
            i += batch_size
        else:
            i = 0
            indices = np.arange(size)
            np.random.shuffle(indices)
            X_copy = X_copy[indices]
            y_copy = y_copy[indices]

# %%
eps = 1e-8
g_ema , d_ema = [] , []
mosaic_img = tf.placeholder(tf.float32 , [None , 256 , 256 , 3] , name = 'mosaic_img')
real_img = tf.placeholder(tf.float32 , [None , 256 , 256 , 3] , name = 'real_img')
keep_prob = tf.placeholder(tf.float32 , name = 'keep_prob')
on_train = tf.placeholder(tf.bool , name = 'on_train')

# %%
with tf.variable_scope('Generator'):
    with tf.variable_scope('Encoder_Stage'):
        conv1 = conv_block(mosaic_img , 64 , 1 , batch_norm = False)
        conv2 , g_en_ema_2 = conv_block(conv1 , 128 , 2)
        conv3 , g_en_ema_3 = conv_block(conv2 , 256 , 3)
        conv4 , g_en_ema_4 = conv_block(conv3 , 512 , 4)
        conv5 , g_en_ema_5 = conv_block(conv4 , 512 , 5)
        conv6 , g_en_ema_6 = conv_block(conv5 , 512 , 6)
        conv7 , g_en_ema_7 = conv_block(conv6 , 512 , 7)
        g_ema.extend([g_en_ema_2 , g_en_ema_3 , g_en_ema_4 , g_en_ema_5 , g_en_ema_6 , g_en_ema_7])

    with tf.variable_scope('Middle_Stage'):    
        conv8 , g_en_ema_8 = conv_block(conv7 , 512 , 8)
        g_ema.append(g_en_ema_8)

    with tf.variable_scope('Decoder_Stage'):
        up1 , g_de_ema_1 = up_block(conv8 , 512 , 1 , dropout = True)
        up2 , g_de_ema_2 = up_block(up1 , 512 , 2 , dropout = True)
        up3 , g_de_ema_3 = up_block(up2 , 512 , 3 , dropout = True)
        up4 , g_de_ema_4 = up_block(up3 , 512 , 4)
        up5 , g_de_ema_5 = up_block(up4 , 256 , 5)
        up6 , g_de_ema_6 = up_block(up5 , 128 , 6)
        up7 , g_de_ema_7 = up_block(up6 , 64 , 7)
        g_ema.extend([g_de_ema_1 , g_de_ema_2 , g_de_ema_3 , g_de_ema_4 , g_de_ema_5 , g_de_ema_6 , g_de_ema_7])
        
    with tf.variable_scope('Output_Stage'):
        fake_img = up_block(up7 , 3 , 8 , stride = 1 , activation_func = tf.nn.tanh , batch_norm = False)


with tf.variable_scope('Discriminator'):
    fake_img_pair = tf.concat([mosaic_img , fake_img] , axis = -1)
    real_img_pair = tf.concat([mosaic_img , real_img] , axis = -1)
    d_fake_1 = conv_block(fake_img_pair , 64 , 1 , batch_norm = False)
    d_real_1 = conv_block(real_img_pair , 64 , 1 , batch_norm = False , reuse = True)
    d_fake_2 , d_ema_2_1 = conv_block(d_fake_1 , 128 , 2)
    d_real_2 , d_ema_2_2 = conv_block(d_real_1 , 128 , 2 , reuse = True)
    d_fake_3 , d_ema_3_1 = conv_block(d_fake_2 , 256 , 3)
    d_real_3 , d_ema_3_2 = conv_block(d_real_2 , 256 , 3 , reuse = True)
    d_fake_4 , d_ema_4_1 = conv_block(d_fake_3 , 512 , 4)
    d_real_4 , d_ema_4_2 = conv_block(d_real_3 , 512 , 4 , reuse = True)
    fake_output_d = conv_block(d_fake_4 , 1 , 5 , stride = 1 , activation_func = tf.nn.sigmoid , batch_norm = False)
    real_output_d = conv_block(d_real_4 , 1 , 5 , stride = 1 , activation_func = tf.nn.sigmoid , batch_norm = False , reuse = True)
    fake_output_d = tf.squeeze(fake_output_d , axis = -1)
    real_output_d = tf.squeeze(real_output_d , axis = -1)
    d_ema.extend([d_ema_2_1 , d_ema_2_2 , d_ema_3_1 , d_ema_3_2 , d_ema_4_1 , d_ema_4_2])

with tf.variable_scope('Discriminator_Loss'):
    d_loss = tf.reduce_mean(-(tf.log(tf.clip_by_value(real_output_d , eps , tf.reduce_max(real_output_d))) +\
                  tf.log(tf.clip_by_value(1 - fake_output_d , eps , tf.reduce_max(1 - fake_output_d)))))

with tf.variable_scope('Generator_Loss'):
    l1_weight = 100
    g_loss_l1 = l1_weight * tf.reduce_mean(tf.abs(fake_img - real_img))
    g_loss_gan = tf.reduce_mean(tf.log(tf.clip_by_value(1 - fake_output_d , eps , tf.reduce_max(1 - fake_output_d))))
    g_loss = g_loss_l1 + g_loss_gan

with tf.variable_scope('Optimizer'):
    g_ema_group , d_ema_group = tf.group(g_ema) , tf.group(d_ema)
    variable_Generator , variable_Discriminator = [] , []
    for v in tf.trainable_variables(): 
        if 'Generator' in v.name : variable_Generator.append(v)
        if 'Discriminator' in v.name : variable_Discriminator.append(v)
    lr_g , lr_d = 2e-4 , 2e-4
    train_Generator = tf.train.AdamOptimizer(lr_g , beta1 = 0.5).minimize(g_loss , var_list = variable_Generator)
    train_Discriminator = tf.train.AdamOptimizer(lr_d , beta1 = 0.5).minimize(d_loss , var_list = variable_Discriminator)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-3-97117c0722f6>:70: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

batch_size = 4
train_batch_generator = batch_generator(mosaic_train , real_train , batch_size)
epochs = 300
num_batch = math.ceil(len(mosaic_train) / batch_size)
for epoch_i in range(0 , epochs):
    d_loss_mean , g_loss_mean = 0 , 0
    for batch_i in range(0 , num_batch):
        x_train_bathch , y_train_bathch = next(train_batch_generator)
        x_train_bathch = (x_train_bathch - 127.5) / 127.5
        y_train_bathch = (y_train_bathch - 127.5) / 127.5
        _ , _ , d_loss_ = sess.run([train_Discriminator , d_ema_group , d_loss] ,
                                    feed_dict = {mosaic_img : x_train_bathch ,
                                                  real_img : y_train_bathch ,
                                                  on_train : True , 
                                                  keep_prob : 0.5})
        _ , _ , g_loss_ = sess.run([train_Generator , g_ema_group , g_loss] ,
                                    feed_dict = {mosaic_img : x_train_bathch ,
                                                  real_img : y_train_bathch ,
                                                  on_train : True , 
                                                  keep_prob : 0.5})

        d_loss_mean += d_loss_
        g_loss_mean += g_loss_

    print('=' * 30)
    print('epoch : {}'.format(epoch_i))
    print('Discriminator_loss_mean : {:.3f}'.format(d_loss_mean / num_batch))
    print('Generator_loss_mean : {:.3f}'.format(g_loss_mean / num_batch))

    if epoch_i % 2 == 0:
        img_pred_train = sess.run(fake_img ,
                                  feed_dict = {mosaic_img : (mosaic_train[:2] - 127.5) / 127.5 ,
                                               on_train : False , 
                                               keep_prob : 1})

        img_pred_test = sess.run(fake_img ,
                                 feed_dict = {mosaic_img : (mosaic_test[:2] - 127.5) / 127.5 ,
                                              on_train : False , 
                                              keep_prob : 1})
      
        img_pred_train = (img_pred_train + 1) * 127.5
        img_pred_test = (img_pred_test + 1) * 127.5
        np.save('img_pred_train_{}'.format(epoch_i) , img_pred_train[0] / 255)
        np.save('img_pred_test_{}'.format(epoch_i) , img_pred_test[0] / 255)
# Out:
# ==============================
# epoch : 0
# Discriminator_loss_mean : 0.298
# Generator_loss_mean : 43.703
# ==============================
# epoch : 1
# Discriminator_loss_mean : 0.005
# Generator_loss_mean : 37.677
# ==============================
# epoch : 2
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 36.612
# ==============================
# epoch : 3
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 35.002
# ==============================
# epoch : 4
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 34.557
# ==============================
# epoch : 5
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 34.067
# ==============================
# epoch : 6
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 33.627
# ==============================
# epoch : 7
# Discriminator_loss_mean : 0.517
# Generator_loss_mean : 32.401
# ==============================
# epoch : 8
# Discriminator_loss_mean : 0.133
# Generator_loss_mean : 32.708
# ==============================
# epoch : 9
# Discriminator_loss_mean : 0.005
# Generator_loss_mean : 32.713
# ==============================
# epoch : 10
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 32.570
# ==============================
# epoch : 11
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 32.093
# ==============================
# epoch : 12
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 31.308
# ==============================
# epoch : 13
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 31.517
# ==============================
# epoch : 14
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 31.535
# ==============================
# epoch : 15
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 31.574
# ==============================
# epoch : 16
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 31.281
# ==============================
# epoch : 17
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.728
# ==============================
# epoch : 18
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.150
# ==============================
# epoch : 19
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.629
# ==============================
# epoch : 20
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.895
# ==============================
# epoch : 21
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.146
# ==============================
# epoch : 22
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.990
# ==============================
# epoch : 23
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.721
# ==============================
# epoch : 24
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 30.077
# ==============================
# epoch : 25
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.720
# ==============================
# epoch : 26
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.469
# ==============================
# epoch : 27
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.409
# ==============================
# epoch : 28
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.351
# ==============================
# epoch : 29
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.218
# ==============================
# epoch : 30
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.884
# ==============================
# epoch : 31
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 29.572
# ==============================
# epoch : 32
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.511
# ==============================
# epoch : 33
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.426
# ==============================
# epoch : 34
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.429
# ==============================
# epoch : 35
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.029
# ==============================
# epoch : 36
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.291
# ==============================
# epoch : 37
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.079
# ==============================
# epoch : 38
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.013
# ==============================
# epoch : 39
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.351
# ==============================
# epoch : 40
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.345
# ==============================
# epoch : 41
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 28.175
# ==============================
# epoch : 42
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.729
# ==============================
# epoch : 43
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.258
# ==============================
# epoch : 44
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.425
# ==============================
# epoch : 45
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.729
# ==============================
# epoch : 46
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.281
# ==============================
# epoch : 47
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.155
# ==============================
# epoch : 48
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.418
# ==============================
# epoch : 49
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.189
# ==============================
# epoch : 50
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.099
# ==============================
# epoch : 51
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 27.133
# ==============================
# epoch : 52
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.748
# ==============================
# epoch : 53
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.504
# ==============================
# epoch : 54
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.818
# ==============================
# epoch : 55
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.463
# ==============================
# epoch : 56
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.776
# ==============================
# epoch : 57
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.704
# ==============================
# epoch : 58
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.575
# ==============================
# epoch : 59
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.569
# ==============================
# epoch : 60
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.239
# ==============================
# epoch : 61
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.333
# ==============================
# epoch : 62
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.286
# ==============================
# epoch : 63
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.113
# ==============================
# epoch : 64
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.166
# ==============================
# epoch : 65
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.861
# ==============================
# epoch : 66
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.505
# ==============================
# epoch : 67
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 26.111
# ==============================
# epoch : 68
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.481
# ==============================
# epoch : 69
# Discriminator_loss_mean : 0.464
# Generator_loss_mean : 25.474
# ==============================
# epoch : 70
# Discriminator_loss_mean : 0.004
# Generator_loss_mean : 25.862
# ==============================
# epoch : 71
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 25.843
# ==============================
# epoch : 72
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 26.087
# ==============================
# epoch : 73
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.845
# ==============================
# epoch : 74
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.415
# ==============================
# epoch : 75
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.510
# ==============================
# epoch : 76
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.539
# ==============================
# epoch : 77
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.571
# ==============================
# epoch : 78
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.265
# ==============================
# epoch : 79
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.351
# ==============================
# epoch : 80
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.441
# ==============================
# epoch : 81
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.390
# ==============================
# epoch : 82
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.119
# ==============================
# epoch : 83
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.415
# ==============================
# epoch : 84
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.981
# ==============================
# epoch : 85
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.011
# ==============================
# epoch : 86
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.976
# ==============================
# epoch : 87
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.048
# ==============================
# epoch : 88
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.744
# ==============================
# epoch : 89
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.199
# ==============================
# epoch : 90
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.112
# ==============================
# epoch : 91
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.051
# ==============================
# epoch : 92
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.636
# ==============================
# epoch : 93
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.123
# ==============================
# epoch : 94
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 25.347
# ==============================
# epoch : 95
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.849
# ==============================
# epoch : 96
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.787
# ==============================
# epoch : 97
# Discriminator_loss_mean : 0.145
# Generator_loss_mean : 24.669
# ==============================
# epoch : 98
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 24.628
# ==============================
# epoch : 99
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 24.421
# ==============================
# epoch : 100
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.514
# ==============================
# epoch : 101
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.704
# ==============================
# epoch : 102
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.410
# ==============================
# epoch : 103
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.687
# ==============================
# epoch : 104
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.798
# ==============================
# epoch : 105
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.812
# ==============================
# epoch : 106
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.613
# ==============================
# epoch : 107
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.344
# ==============================
# epoch : 108
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.319
# ==============================
# epoch : 109
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.356
# ==============================
# epoch : 110
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.449
# ==============================
# epoch : 111
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.168
# ==============================
# epoch : 112
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.297
# ==============================
# epoch : 113
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.320
# ==============================
# epoch : 114
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.421
# ==============================
# epoch : 115
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.263
# ==============================
# epoch : 116
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.102
# ==============================
# epoch : 117
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.219
# ==============================
# epoch : 118
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.356
# ==============================
# epoch : 119
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.078
# ==============================
# epoch : 120
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.167
# ==============================
# epoch : 121
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.689
# ==============================
# epoch : 122
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.472
# ==============================
# epoch : 123
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.874
# ==============================
# epoch : 124
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.998
# ==============================
# epoch : 125
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.051
# ==============================
# epoch : 126
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.917
# ==============================
# epoch : 127
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.664
# ==============================
# epoch : 128
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.656
# ==============================
# epoch : 129
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.566
# ==============================
# epoch : 130
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.598
# ==============================
# epoch : 131
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.527
# ==============================
# epoch : 132
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.618
# ==============================
# epoch : 133
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.624
# ==============================
# epoch : 134
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.700
# ==============================
# epoch : 135
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.504
# ==============================
# epoch : 136
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.558
# ==============================
# epoch : 137
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.526
# ==============================
# epoch : 138
# Discriminator_loss_mean : 0.161
# Generator_loss_mean : 23.526
# ==============================
# epoch : 139
# Discriminator_loss_mean : 0.002
# Generator_loss_mean : 23.488
# ==============================
# epoch : 140
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 23.392
# ==============================
# epoch : 141
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.655
# ==============================
# epoch : 142
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.207
# ==============================
# epoch : 143
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.828
# ==============================
# epoch : 144
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 24.852
# ==============================
# epoch : 145
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.643
# ==============================
# epoch : 146
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.730
# ==============================
# epoch : 147
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.624
# ==============================
# epoch : 148
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.391
# ==============================
# epoch : 149
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.342
# ==============================
# epoch : 150
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.368
# ==============================
# epoch : 151
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.348
# ==============================
# epoch : 152
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.002
# ==============================
# epoch : 153
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.146
# ==============================
# epoch : 154
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.080
# ==============================
# epoch : 155
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.011
# ==============================
# epoch : 156
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.095
# ==============================
# epoch : 157
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.986
# ==============================
# epoch : 158
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.155
# ==============================
# epoch : 159
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.975
# ==============================
# epoch : 160
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.966
# ==============================
# epoch : 161
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.863
# ==============================
# epoch : 162
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.978
# ==============================
# epoch : 163
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 23.032
# ==============================
# epoch : 164
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.764
# ==============================
# epoch : 165
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.987
# ==============================
# epoch : 166
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.957
# ==============================
# epoch : 167
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.643
# ==============================
# epoch : 168
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.850
# ==============================
# epoch : 169
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.734
# ==============================
# epoch : 170
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.710
# ==============================
# epoch : 171
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.690
# ==============================
# epoch : 172
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.700
# ==============================
# epoch : 173
# Discriminator_loss_mean : 0.120
# Generator_loss_mean : 22.576
# ==============================
# epoch : 174
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 22.596
# ==============================
# epoch : 175
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.639
# ==============================
# epoch : 176
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.532
# ==============================
# epoch : 177
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.731
# ==============================
# epoch : 178
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.613
# ==============================
# epoch : 179
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.396
# ==============================
# epoch : 180
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.722
# ==============================
# epoch : 181
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.689
# ==============================
# epoch : 182
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.512
# ==============================
# epoch : 183
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.440
# ==============================
# epoch : 184
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.331
# ==============================
# epoch : 185
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.521
# ==============================
# epoch : 186
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.119
# ==============================
# epoch : 187
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.456
# ==============================
# epoch : 188
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.213
# ==============================
# epoch : 189
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.276
# ==============================
# epoch : 190
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.329
# ==============================
# epoch : 191
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.391
# ==============================
# epoch : 192
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.290
# ==============================
# epoch : 193
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.151
# ==============================
# epoch : 194
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.243
# ==============================
# epoch : 195
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.184
# ==============================
# epoch : 196
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.259
# ==============================
# epoch : 197
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.108
# ==============================
# epoch : 198
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.973
# ==============================
# epoch : 199
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.105
# ==============================
# epoch : 200
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.967
# ==============================
# epoch : 201
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.166
# ==============================
# epoch : 202
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.818
# ==============================
# epoch : 203
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.007
# ==============================
# epoch : 204
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.016
# ==============================
# epoch : 205
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.980
# ==============================
# epoch : 206
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.967
# ==============================
# epoch : 207
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.939
# ==============================
# epoch : 208
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.914
# ==============================
# epoch : 209
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.816
# ==============================
# epoch : 210
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.192
# ==============================
# epoch : 211
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.929
# ==============================
# epoch : 212
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.837
# ==============================
# epoch : 213
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.835
# ==============================
# epoch : 214
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.837
# ==============================
# epoch : 215
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.809
# ==============================
# epoch : 216
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.764
# ==============================
# epoch : 217
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.696
# ==============================
# epoch : 218
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.796
# ==============================
# epoch : 219
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.675
# ==============================
# epoch : 220
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.524
# ==============================
# epoch : 221
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.607
# ==============================
# epoch : 222
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.648
# ==============================
# epoch : 223
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.762
# ==============================
# epoch : 224
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.549
# ==============================
# epoch : 225
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.717
# ==============================
# epoch : 226
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.536
# ==============================
# epoch : 227
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.465
# ==============================
# epoch : 228
# Discriminator_loss_mean : 0.060
# Generator_loss_mean : 21.663
# ==============================
# epoch : 229
# Discriminator_loss_mean : 0.001
# Generator_loss_mean : 21.552
# ==============================
# epoch : 230
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.481
# ==============================
# epoch : 231
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.559
# ==============================
# epoch : 232
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.484
# ==============================
# epoch : 233
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.379
# ==============================
# epoch : 234
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.372
# ==============================
# epoch : 235
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.343
# ==============================
# epoch : 236
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.346
# ==============================
# epoch : 237
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.196
# ==============================
# epoch : 238
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.392
# ==============================
# epoch : 239
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.315
# ==============================
# epoch : 240
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.271
# ==============================
# epoch : 241
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.148
# ==============================
# epoch : 242
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.248
# ==============================
# epoch : 243
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.381
# ==============================
# epoch : 244
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.196
# ==============================
# epoch : 245
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.097
# ==============================
# epoch : 246
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.184
# ==============================
# epoch : 247
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.245
# ==============================
# epoch : 248
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.090
# ==============================
# epoch : 249
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.348
# ==============================
# epoch : 250
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.213
# ==============================
# epoch : 251
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.227
# ==============================
# epoch : 252
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.630
# ==============================
# epoch : 253
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.253
# ==============================
# epoch : 254
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.024
# ==============================
# epoch : 255
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.044
# ==============================
# epoch : 256
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.053
# ==============================
# epoch : 257
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.829
# ==============================
# epoch : 258
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.814
# ==============================
# epoch : 259
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.068
# ==============================
# epoch : 260
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.926
# ==============================
# epoch : 261
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.119
# ==============================
# epoch : 262
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.939
# ==============================
# epoch : 263
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.924
# ==============================
# epoch : 264
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.109
# ==============================
# epoch : 265
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.571
# ==============================
# epoch : 266
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.031
# ==============================
# epoch : 267
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.931
# ==============================
# epoch : 268
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.759
# ==============================
# epoch : 269
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.947
# ==============================
# epoch : 270
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.913
# ==============================
# epoch : 271
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.627
# ==============================
# epoch : 272
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.899
# ==============================
# epoch : 273
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.704
# ==============================
# epoch : 274
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.744
# ==============================
# epoch : 275
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.507
# ==============================
# epoch : 276
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.828
# ==============================
# epoch : 277
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.858
# ==============================
# epoch : 278
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.766
# ==============================
# epoch : 279
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.679
# ==============================
# epoch : 280
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.785
# ==============================
# epoch : 281
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.730
# ==============================
# epoch : 282
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.620
# ==============================
# epoch : 283
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.546
# ==============================
# epoch : 284
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.651
# ==============================
# epoch : 285
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.864
# ==============================
# epoch : 286
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.439
# ==============================
# epoch : 287
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.698
# ==============================
# epoch : 288
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.659
# ==============================
# epoch : 289
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.554
# ==============================
# epoch : 290
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.600
# ==============================
# epoch : 291
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.672
# ==============================
# epoch : 292
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 22.641
# ==============================
# epoch : 293
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 21.347
# ==============================
# epoch : 294
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.729
# ==============================
# epoch : 295
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.854
# ==============================
# epoch : 296
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.608
# ==============================
# epoch : 297
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.532
# ==============================
# epoch : 298
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.372
# ==============================
# epoch : 299
# Discriminator_loss_mean : 0.000
# Generator_loss_mean : 20.256

# %%
for img_idx in [0] + list(range(6 , 20)):
    img_pred =  sess.run(fake_img , 
                feed_dict = {mosaic_img : np.expand_dims((mosaic_test[img_idx] - 127.5) / 127.5 , axis = 0)  ,
                        on_train : False , 
                        keep_prob : 1})

    fig , ax = plt.subplots(1 , 3 , figsize = (12 , 12))

    ax[0].imshow(real_test[img_idx] / 255.)
    ax[0].set_xticks([])
    ax[0].set_yticks([])
    ax[0].set_title('Original Image')

    ax[1].imshow(mosaic_test[img_idx] / 255.)
    ax[1].set_xticks([])
    ax[1].set_yticks([])
    ax[1].set_title('Mosaic Image')

    ax[2].imshow((img_pred[0] + 1) * 127.5 / 255)
    ax[2].set_xticks([])
    ax[2].set_yticks([])
    ax[2].set_title('Predicted Image')

np.save('img_pred' , img_pred)
del mosaic_test , real_test

# %%
saver = tf.train.Saver()
saver.save(sess , 'mosaic_model/mosaic_model')
print('Model Trained and Saved')
# Out:
# Model Trained and Saved
