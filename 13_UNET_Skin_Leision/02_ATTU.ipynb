# %% [markdown]
# ### 請解壓縮data.rar，取得本程式之數據

# %%
from google.colab import drive
# %tensorflow_version 1.x
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import numpy as np
from keras.layers import Conv2D , UpSampling2D , MaxPooling2D , concatenate
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import math
import cv2
import os

drive.mount('/content/gdrive')
path = os.path.join(os.getcwd() , 'gdrive' , 'My Drive' , 'unet_ISIC-2017')
os.chdir(path)
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# Mounted at /content/gdrive

# %%
images = np.load('images.npy')
masks = np.load('masks.npy')
masks = np.expand_dims(masks , axis = -1)

(x_train , x_test , y_train , y_test) =\
train_test_split(images ,
                 masks,
                 test_size = 0.1 ,
                 random_state = 42)

del images , masks

# %%
def metrics(y_true , y_pred):
    y_true = np.reshape(y_true , [-1])
    y_pred = np.reshape(y_pred , [-1])
    y_true = np.where(y_true > 0.5 , 1 , 0)
    y_pred = np.where(y_pred > 0.5 , 1 , 0)
    cm = confusion_matrix(y_true , y_pred)
    accuracy = (cm[0 , 0] + cm[1 , 1]) / np.sum(cm)
    recall = cm[1 , 1] / (cm[1 , 0] + cm[1 , 1])
    precision = cm[1 , 1] / (cm[0 , 1] + cm[1 , 1])
    f1_score = 2 * recall * precision / (recall + precision)
    return accuracy , recall , precision , f1_score


def batch_norm_layer(inputs , on_train , convolution):
    # the dimension you wanna normalize, here [0] for batch
    # for image, you wanna do [0 , 1 , 2] for [batch , height , width] but not channel
    if convolution:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0 , 1 , 2] , name = 'mean_var')
    else:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0] , name = 'mean_var')
    
    ema = tf.train.ExponentialMovingAverage(decay = 0.75)
    ema_apply_op = ema.apply([fc_mean , fc_var])
    mean = tf.cond(on_train , lambda : fc_mean , lambda : ema.average(fc_mean))
    var = tf.cond(on_train , lambda : fc_var , lambda : ema.average(fc_var))
    
    scale = tf.Variable(tf.ones([1 , inputs.shape[-1].value]) , name = 'scale') 
    shift = tf.Variable(tf.zeros([1 , inputs.shape[-1].value]) , name = 'shift')
    temp = (inputs - mean) / tf.sqrt(var + 0.001)
    outputs = tf.multiply(temp , scale) + shift
  
    return outputs , ema_apply_op


def conv_block(inputs , n_filter , kernel_size = 3 , activation = tf.nn.relu ,
               padding = 'same' , kernel_initializer = 'glorot_uniform' , batch_norm = True):
    conv = Conv2D(n_filter , kernel_size , activation = None , padding = padding ,
                   kernel_initializer = kernel_initializer)(inputs)

    if batch_norm: conv , ema1 = batch_norm_layer(conv , on_train , True)

    conv = activation(conv)
    conv = Conv2D(n_filter , kernel_size , activation = None , padding = padding ,
                   kernel_initializer = kernel_initializer)(conv)

    if batch_norm: conv , ema2 = batch_norm_layer(conv , on_train , True)

    conv = activation(conv)
    return conv , [ema1 , ema2]


def up_block(inputs , n_filter , kernel_size = 3 , activation =  tf.nn.relu ,
             padding = 'same' , kernel_initializer = 'glorot_uniform' , batch_norm = True):
    up_ = UpSampling2D(size = (2 , 2))(inputs)
    up = Conv2D(n_filter , kernel_size , activation = None , padding = padding ,
                kernel_initializer = kernel_initializer)(up_)

    if batch_norm: up , ema = batch_norm_layer(up , on_train , True)

    up = activation(up)
    return up , ema


def attention(conv , up , n_filter , kernel_size = 1 , 
              padding = 'same' , kernel_initializer = 'glorot_uniform'):
    g = Conv2D(n_filter , kernel_size , padding = padding , 
               kernel_initializer = kernel_initializer)(up)
    x = Conv2D(n_filter , kernel_size , padding = padding , 
               kernel_initializer = kernel_initializer)(conv)
    sigma = tf.add(g , x)
    sigma = tf.nn.relu(sigma)
    sigma = Conv2D(1 , kernel_size , padding = padding)(sigma)
    alpha = tf.nn.sigmoid(sigma)
    output = alpha * conv
    return output


def batch_generator(X , y , batch_size):
    size = X.shape[0]
    X_copy = X.copy()
    y_copy = y.copy()
    indices = np.arange(size)
    np.random.shuffle(indices)
    X_copy = X_copy[indices]
    y_copy = y_copy[indices]
    i = 0
    while True:
        if i + batch_size <= size:
            yield X_copy[i : i + batch_size] , y_copy[i : i + batch_size]
            i += batch_size
        else:
            i = 0
            indices = np.arange(size)
            np.random.shuffle(indices)
            X_copy = X_copy[indices]
            y_copy = y_copy[indices]

# %%
ema = []
inputs = tf.placeholder(tf.float32 , [None , 256 , 256 , 3] , name = 'inputs')
y_true = tf.placeholder(tf.float32 , [None , 256 , 256 , 1] , name = 'y_true')
keep_prob = tf.placeholder(tf.float32 , name = 'keep_prob')
on_train = tf.placeholder(tf.bool , name = 'on_train')

# %%
with tf.variable_scope('Encoder_Stage'):
    with tf.variable_scope('Conv1'):
        conv1 , ema1 = conv_block(inputs , 64)
        pool1 = MaxPooling2D(pool_size = (2 , 2))(conv1)
        ema.extend(ema1)

    with tf.variable_scope('Conv2'):
        conv2 , ema2 = conv_block(pool1 , 128)
        pool2 = MaxPooling2D(pool_size = (2 , 2))(conv2)
        ema.extend(ema2)
    
    with tf.variable_scope('Conv3'):
        conv3 , ema3 = conv_block(pool2 , 256)
        pool3 = MaxPooling2D(pool_size = (2 , 2))(conv3)
        ema.extend(ema3)

    with tf.variable_scope('Conv4'):
        conv4 , ema4 = conv_block(pool3 , 512)
        pool4 = MaxPooling2D(pool_size = (2 , 2))(conv4)
        ema.extend(ema4)


with tf.variable_scope('Middle_Stage'):
    conv5 , ema5 = conv_block(pool4 , 1024)
    drop5 = tf.nn.dropout(conv5 , keep_prob)
    ema.extend(ema5)


with tf.variable_scope('Decoder_Stage'):
    with tf.variable_scope('Conv5'):
        up6 , ema6_1 = up_block(drop5 , 512)
        att6 = attention(conv4 , up6 , 512)
        concat6 = concatenate([conv4 , att6] , axis = -1)
        conv6 , ema6_2 = conv_block(concat6 , 512)
        ema.extend([ema6_1])
        ema.extend(ema6_2)

    with tf.variable_scope('Conv7'):
        up7 , ema7_1 = up_block(conv6 , 256)
        att7 = attention(conv3 , up7 , 256)
        concat7 = concatenate([conv3 , att7] , axis = -1)
        conv7 , ema7_2 = conv_block(concat7 , 256)
        ema.extend([ema7_1])
        ema.extend(ema7_2)

    with tf.variable_scope('Conv8'):
        up8 , ema8_1 = up_block(conv7 , 128)
        att8 = attention(conv2 , up8 , 128)
        concat8 = concatenate([conv2 , att8] , axis = -1)
        conv8 , ema8_2 = conv_block(concat8 , 128)
        ema.extend([ema8_1])
        ema.extend(ema8_2)

    with tf.variable_scope('Conv9'):
        up9 , ema9_1 = up_block(conv8 , 64)
        att9 = attention(conv1 , up9 , 64)
        concat9 = concatenate([conv1 , att9] , axis = -1)
        conv9 , ema9_2 = conv_block(concat9 , 64)
        ema.extend([ema9_1])
        ema.extend(ema9_2)


with tf.variable_scope('Output_Stage'):
    y_pred = Conv2D(1 , 1 , activation = 'sigmoid' , padding = 'same' ,
                    kernel_initializer = 'glorot_uniform')(conv9)


with tf.variable_scope('Optimizer'):
    update_ema = tf.group(ema)
    cross_entropy = y_true * tf.log(tf.clip_by_value(y_pred , 1e-8 , tf.reduce_max(y_pred))) +\
                    (1 - y_true) * tf.log(tf.clip_by_value(1 - y_pred , 1e-8 , tf.reduce_max(1 - y_pred)))
    loss = -tf.reduce_mean(cross_entropy)
    train_op = tf.train.AdamOptimizer(1e-4).minimize(loss)

with tf.variable_scope('IOU'):
    smooth = 1e-8
    intersection = tf.reduce_sum(tf.abs(y_true * y_pred))
    sum_ = tf.reduce_sum(tf.square(y_true)) + tf.reduce_sum(tf.square(y_pred))
    iou = (intersection + smooth) / (sum_ - intersection + smooth)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From <ipython-input-5-2ee96e2a2bec>:25: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
image_grnerator = ImageDataGenerator(rotation_range = 0.1,
                                     width_shift_range = 0.1,
                                     height_shift_range = 0.1,
                                     shear_range = 0.02 ,
                                     zoom_range = 0.02,
                                     horizontal_flip = True ,
                                     fill_mode = 'nearest')

mask_grnerator = ImageDataGenerator(rotation_range = 0.1,
                                    width_shift_range = 0.1,
                                    height_shift_range = 0.1,
                                    shear_range = 0.02 ,
                                    zoom_range = 0.02,
                                    horizontal_flip = True ,
                                    fill_mode = 'nearest')

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

batch_size = 8
train_batch_generator = batch_generator(x_train , y_train , batch_size)
epochs = 100
num_batch = math.ceil(len(x_train) / batch_size)
for epoch_i in range(0 , epochs):
    train_loss_mean = 0
    for batch_i in range(0 , num_batch):
        x_train_bathch , y_train_bathch = next(train_batch_generator)
        x_train_bathch_aug = image_grnerator.flow(x_train_bathch , np.arange(8) , shuffle = False , batch_size = batch_size , seed = 1)
        y_train_bathch_aug = mask_grnerator.flow(y_train_bathch , np.arange(8) , shuffle = False , batch_size = batch_size , seed = 1)
        x_train_bathch_aug = x_train_bathch_aug[0][0]
        y_train_bathch_aug = y_train_bathch_aug[0][0]

        _ , _ , train_loss = sess.run([train_op , update_ema , loss] ,
                                      feed_dict = {inputs : x_train_bathch_aug ,
                                                   y_true : y_train_bathch_aug / 255. ,
                                                   keep_prob : 0.5 ,
                                                   on_train : True})
        train_loss_mean += train_loss

    print('=' * 30)
    print('epoch : {}'.format(epoch_i))
    print('train_loss_mean : {:.3f}'.format(train_loss_mean / num_batch))

    test_loss_sum = 0
    test_iou_sum = 0
    y_test_pred = np.zeros([len(x_test) , 256 , 256 , 1])
    for test_batch_i in range(0 , 10):
        test_loss , test_iou , y_test_pred_ =\
        sess.run([loss , iou , y_pred] ,
                feed_dict = {inputs : x_test[10*test_batch_i : 10*(test_batch_i+1)]  ,
                             y_true : y_test[10*test_batch_i : 10*(test_batch_i+1)]  / 255. ,
                             keep_prob : 1 ,
                             on_train : False})
        test_loss_sum += test_loss
        test_iou_sum += test_iou
        y_test_pred[10*test_batch_i : 10*(test_batch_i+1)]  = y_test_pred_

    accuracy_test , recall_test , precision_test , f1_score_test = metrics(y_test , y_test_pred)
    print('*' * 30)
    print('test_loss : {:.3f}'.format(test_loss_sum / 10))
    print('test_iou : {:.3f}'.format(test_iou_sum / 10))
    print('test_accuracy : {:.2%}'.format(accuracy_test))
    print('test_recall : {:.3f}'.format(recall_test))
    print('test_precision : {:.3f}'.format(precision_test))
    print('test_f1_score : {:.3f}'.format(f1_score_test))
    print('*' * 30)
# Out:
# ==============================
# epoch : 0
# train_loss_mean : 0.363
# ******************************
# test_loss : 0.257
# test_iou : 0.739
# test_accuracy : 91.37%
# test_recall : 0.750
# test_precision : 0.909
# test_f1_score : 0.822
# ******************************
# ==============================
# epoch : 1
# train_loss_mean : 0.254
# ******************************
# test_loss : 0.209
# test_iou : 0.803
# test_accuracy : 93.43%
# test_recall : 0.845
# test_precision : 0.901
# test_f1_score : 0.872
# ******************************
# ==============================
# epoch : 2
# train_loss_mean : 0.220
# ******************************
# test_loss : 0.173
# test_iou : 0.838
# test_accuracy : 94.47%
# test_recall : 0.882
# test_precision : 0.908
# test_f1_score : 0.894
# ******************************
# ==============================
# epoch : 3
# train_loss_mean : 0.197
# ******************************
# test_loss : 0.177
# test_iou : 0.830
# test_accuracy : 94.24%
# test_recall : 0.835
# test_precision : 0.941
# test_f1_score : 0.885
# ******************************
# ==============================
# epoch : 4
# train_loss_mean : 0.185
# ******************************
# test_loss : 0.156
# test_iou : 0.842
# test_accuracy : 94.40%
# test_recall : 0.835
# test_precision : 0.947
# test_f1_score : 0.888
# ******************************
# ==============================
# epoch : 5
# train_loss_mean : 0.168
# ******************************
# test_loss : 0.149
# test_iou : 0.851
# test_accuracy : 94.64%
# test_recall : 0.837
# test_precision : 0.956
# test_f1_score : 0.892
# ******************************
# ==============================
# epoch : 6
# train_loss_mean : 0.164
# ******************************
# test_loss : 0.154
# test_iou : 0.847
# test_accuracy : 94.64%
# test_recall : 0.839
# test_precision : 0.954
# test_f1_score : 0.892
# ******************************
# ==============================
# epoch : 7
# train_loss_mean : 0.164
# ******************************
# test_loss : 0.152
# test_iou : 0.844
# test_accuracy : 94.62%
# test_recall : 0.870
# test_precision : 0.923
# test_f1_score : 0.896
# ******************************
# ==============================
# epoch : 8
# train_loss_mean : 0.155
# ******************************
# test_loss : 0.132
# test_iou : 0.867
# test_accuracy : 95.16%
# test_recall : 0.865
# test_precision : 0.948
# test_f1_score : 0.905
# ******************************
# ==============================
# epoch : 9
# train_loss_mean : 0.144
# ******************************
# test_loss : 0.134
# test_iou : 0.856
# test_accuracy : 94.74%
# test_recall : 0.829
# test_precision : 0.968
# test_f1_score : 0.893
# ******************************
# ==============================
# epoch : 10
# train_loss_mean : 0.133
# ******************************
# test_loss : 0.124
# test_iou : 0.873
# test_accuracy : 95.24%
# test_recall : 0.891
# test_precision : 0.926
# test_f1_score : 0.909
# ******************************
# ==============================
# epoch : 11
# train_loss_mean : 0.140
# ******************************
# test_loss : 0.119
# test_iou : 0.877
# test_accuracy : 95.39%
# test_recall : 0.895
# test_precision : 0.928
# test_f1_score : 0.912
# ******************************
# ==============================
# epoch : 12
# train_loss_mean : 0.130
# ******************************
# test_loss : 0.114
# test_iou : 0.885
# test_accuracy : 95.67%
# test_recall : 0.878
# test_precision : 0.955
# test_f1_score : 0.915
# ******************************
# ==============================
# epoch : 13
# train_loss_mean : 0.124
# ******************************
# test_loss : 0.127
# test_iou : 0.873
# test_accuracy : 95.19%
# test_recall : 0.904
# test_precision : 0.914
# test_f1_score : 0.909
# ******************************
# ==============================
# epoch : 14
# train_loss_mean : 0.132
# ******************************
# test_loss : 0.114
# test_iou : 0.881
# test_accuracy : 95.46%
# test_recall : 0.890
# test_precision : 0.936
# test_f1_score : 0.912
# ******************************
# ==============================
# epoch : 15
# train_loss_mean : 0.124
# ******************************
# test_loss : 0.112
# test_iou : 0.885
# test_accuracy : 95.66%
# test_recall : 0.883
# test_precision : 0.950
# test_f1_score : 0.915
# ******************************
# ==============================
# epoch : 16
# train_loss_mean : 0.126
# ******************************
# test_loss : 0.119
# test_iou : 0.870
# test_accuracy : 94.89%
# test_recall : 0.847
# test_precision : 0.955
# test_f1_score : 0.898
# ******************************
# ==============================
# epoch : 17
# train_loss_mean : 0.117
# ******************************
# test_loss : 0.121
# test_iou : 0.873
# test_accuracy : 95.30%
# test_recall : 0.866
# test_precision : 0.953
# test_f1_score : 0.907
# ******************************
# ==============================
# epoch : 18
# train_loss_mean : 0.120
# ******************************
# test_loss : 0.108
# test_iou : 0.889
# test_accuracy : 95.77%
# test_recall : 0.884
# test_precision : 0.953
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 19
# train_loss_mean : 0.113
# ******************************
# test_loss : 0.108
# test_iou : 0.886
# test_accuracy : 95.57%
# test_recall : 0.876
# test_precision : 0.953
# test_f1_score : 0.913
# ******************************
# ==============================
# epoch : 20
# train_loss_mean : 0.116
# ******************************
# test_loss : 0.109
# test_iou : 0.886
# test_accuracy : 95.77%
# test_recall : 0.895
# test_precision : 0.943
# test_f1_score : 0.918
# ******************************
# ==============================
# epoch : 21
# train_loss_mean : 0.113
# ******************************
# test_loss : 0.109
# test_iou : 0.883
# test_accuracy : 95.44%
# test_recall : 0.873
# test_precision : 0.951
# test_f1_score : 0.910
# ******************************
# ==============================
# epoch : 22
# train_loss_mean : 0.110
# ******************************
# test_loss : 0.110
# test_iou : 0.883
# test_accuracy : 95.61%
# test_recall : 0.887
# test_precision : 0.944
# test_f1_score : 0.915
# ******************************
# ==============================
# epoch : 23
# train_loss_mean : 0.108
# ******************************
# test_loss : 0.115
# test_iou : 0.878
# test_accuracy : 95.36%
# test_recall : 0.859
# test_precision : 0.962
# test_f1_score : 0.908
# ******************************
# ==============================
# epoch : 24
# train_loss_mean : 0.113
# ******************************
# test_loss : 0.102
# test_iou : 0.889
# test_accuracy : 95.75%
# test_recall : 0.885
# test_precision : 0.952
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 25
# train_loss_mean : 0.104
# ******************************
# test_loss : 0.107
# test_iou : 0.882
# test_accuracy : 95.44%
# test_recall : 0.857
# test_precision : 0.967
# test_f1_score : 0.909
# ******************************
# ==============================
# epoch : 26
# train_loss_mean : 0.103
# ******************************
# test_loss : 0.107
# test_iou : 0.884
# test_accuracy : 95.55%
# test_recall : 0.890
# test_precision : 0.939
# test_f1_score : 0.914
# ******************************
# ==============================
# epoch : 27
# train_loss_mean : 0.098
# ******************************
# test_loss : 0.116
# test_iou : 0.871
# test_accuracy : 95.10%
# test_recall : 0.840
# test_precision : 0.971
# test_f1_score : 0.901
# ******************************
# ==============================
# epoch : 28
# train_loss_mean : 0.102
# ******************************
# test_loss : 0.097
# test_iou : 0.892
# test_accuracy : 95.80%
# test_recall : 0.886
# test_precision : 0.953
# test_f1_score : 0.918
# ******************************
# ==============================
# epoch : 29
# train_loss_mean : 0.097
# ******************************
# test_loss : 0.100
# test_iou : 0.891
# test_accuracy : 95.79%
# test_recall : 0.874
# test_precision : 0.964
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 30
# train_loss_mean : 0.109
# ******************************
# test_loss : 0.105
# test_iou : 0.882
# test_accuracy : 95.27%
# test_recall : 0.837
# test_precision : 0.982
# test_f1_score : 0.904
# ******************************
# ==============================
# epoch : 31
# train_loss_mean : 0.099
# ******************************
# test_loss : 0.101
# test_iou : 0.886
# test_accuracy : 95.48%
# test_recall : 0.853
# test_precision : 0.973
# test_f1_score : 0.909
# ******************************
# ==============================
# epoch : 32
# train_loss_mean : 0.095
# ******************************
# test_loss : 0.094
# test_iou : 0.896
# test_accuracy : 95.91%
# test_recall : 0.884
# test_precision : 0.959
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 33
# train_loss_mean : 0.097
# ******************************
# test_loss : 0.106
# test_iou : 0.884
# test_accuracy : 95.57%
# test_recall : 0.863
# test_precision : 0.966
# test_f1_score : 0.912
# ******************************
# ==============================
# epoch : 34
# train_loss_mean : 0.102
# ******************************
# test_loss : 0.102
# test_iou : 0.890
# test_accuracy : 95.79%
# test_recall : 0.922
# test_precision : 0.920
# test_f1_score : 0.921
# ******************************
# ==============================
# epoch : 35
# train_loss_mean : 0.101
# ******************************
# test_loss : 0.102
# test_iou : 0.890
# test_accuracy : 95.80%
# test_recall : 0.876
# test_precision : 0.963
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 36
# train_loss_mean : 0.100
# ******************************
# test_loss : 0.095
# test_iou : 0.896
# test_accuracy : 95.95%
# test_recall : 0.897
# test_precision : 0.947
# test_f1_score : 0.922
# ******************************
# ==============================
# epoch : 37
# train_loss_mean : 0.090
# ******************************
# test_loss : 0.104
# test_iou : 0.883
# test_accuracy : 95.44%
# test_recall : 0.857
# test_precision : 0.968
# test_f1_score : 0.909
# ******************************
# ==============================
# epoch : 38
# train_loss_mean : 0.094
# ******************************
# test_loss : 0.116
# test_iou : 0.876
# test_accuracy : 95.21%
# test_recall : 0.856
# test_precision : 0.959
# test_f1_score : 0.905
# ******************************
# ==============================
# epoch : 39
# train_loss_mean : 0.093
# ******************************
# test_loss : 0.102
# test_iou : 0.887
# test_accuracy : 95.53%
# test_recall : 0.865
# test_precision : 0.963
# test_f1_score : 0.911
# ******************************
# ==============================
# epoch : 40
# train_loss_mean : 0.093
# ******************************
# test_loss : 0.101
# test_iou : 0.892
# test_accuracy : 95.75%
# test_recall : 0.873
# test_precision : 0.963
# test_f1_score : 0.916
# ******************************
# ==============================
# epoch : 41
# train_loss_mean : 0.085
# ******************************
# test_loss : 0.114
# test_iou : 0.876
# test_accuracy : 95.29%
# test_recall : 0.844
# test_precision : 0.975
# test_f1_score : 0.905
# ******************************
# ==============================
# epoch : 42
# train_loss_mean : 0.088
# ******************************
# test_loss : 0.107
# test_iou : 0.885
# test_accuracy : 95.56%
# test_recall : 0.891
# test_precision : 0.939
# test_f1_score : 0.914
# ******************************
# ==============================
# epoch : 43
# train_loss_mean : 0.092
# ******************************
# test_loss : 0.119
# test_iou : 0.867
# test_accuracy : 94.82%
# test_recall : 0.848
# test_precision : 0.952
# test_f1_score : 0.897
# ******************************
# ==============================
# epoch : 44
# train_loss_mean : 0.090
# ******************************
# test_loss : 0.110
# test_iou : 0.882
# test_accuracy : 95.45%
# test_recall : 0.853
# test_precision : 0.972
# test_f1_score : 0.909
# ******************************
# ==============================
# epoch : 45
# train_loss_mean : 0.097
# ******************************
# test_loss : 0.110
# test_iou : 0.880
# test_accuracy : 95.39%
# test_recall : 0.880
# test_precision : 0.942
# test_f1_score : 0.910
# ******************************
# ==============================
# epoch : 46
# train_loss_mean : 0.092
# ******************************
# test_loss : 0.097
# test_iou : 0.895
# test_accuracy : 95.94%
# test_recall : 0.899
# test_precision : 0.945
# test_f1_score : 0.922
# ******************************
# ==============================
# epoch : 47
# train_loss_mean : 0.082
# ******************************
# test_loss : 0.095
# test_iou : 0.895
# test_accuracy : 95.91%
# test_recall : 0.892
# test_precision : 0.951
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 48
# train_loss_mean : 0.087
# ******************************
# test_loss : 0.110
# test_iou : 0.886
# test_accuracy : 95.68%
# test_recall : 0.917
# test_precision : 0.920
# test_f1_score : 0.918
# ******************************
# ==============================
# epoch : 49
# train_loss_mean : 0.086
# ******************************
# test_loss : 0.096
# test_iou : 0.894
# test_accuracy : 95.93%
# test_recall : 0.899
# test_precision : 0.945
# test_f1_score : 0.921
# ******************************
# ==============================
# epoch : 50
# train_loss_mean : 0.083
# ******************************
# test_loss : 0.100
# test_iou : 0.891
# test_accuracy : 95.81%
# test_recall : 0.869
# test_precision : 0.970
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 51
# train_loss_mean : 0.078
# ******************************
# test_loss : 0.105
# test_iou : 0.884
# test_accuracy : 95.46%
# test_recall : 0.850
# test_precision : 0.976
# test_f1_score : 0.909
# ******************************
# ==============================
# epoch : 52
# train_loss_mean : 0.079
# ******************************
# test_loss : 0.098
# test_iou : 0.894
# test_accuracy : 95.91%
# test_recall : 0.879
# test_precision : 0.964
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 53
# train_loss_mean : 0.077
# ******************************
# test_loss : 0.105
# test_iou : 0.887
# test_accuracy : 95.60%
# test_recall : 0.879
# test_precision : 0.952
# test_f1_score : 0.914
# ******************************
# ==============================
# epoch : 54
# train_loss_mean : 0.081
# ******************************
# test_loss : 0.092
# test_iou : 0.897
# test_accuracy : 95.92%
# test_recall : 0.887
# test_precision : 0.956
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 55
# train_loss_mean : 0.084
# ******************************
# test_loss : 0.093
# test_iou : 0.897
# test_accuracy : 95.99%
# test_recall : 0.894
# test_precision : 0.953
# test_f1_score : 0.922
# ******************************
# ==============================
# epoch : 56
# train_loss_mean : 0.078
# ******************************
# test_loss : 0.096
# test_iou : 0.892
# test_accuracy : 95.78%
# test_recall : 0.880
# test_precision : 0.958
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 57
# train_loss_mean : 0.079
# ******************************
# test_loss : 0.092
# test_iou : 0.897
# test_accuracy : 95.96%
# test_recall : 0.892
# test_precision : 0.952
# test_f1_score : 0.921
# ******************************
# ==============================
# epoch : 58
# train_loss_mean : 0.076
# ******************************
# test_loss : 0.093
# test_iou : 0.899
# test_accuracy : 96.13%
# test_recall : 0.906
# test_precision : 0.946
# test_f1_score : 0.925
# ******************************
# ==============================
# epoch : 59
# train_loss_mean : 0.073
# ******************************
# test_loss : 0.095
# test_iou : 0.895
# test_accuracy : 95.85%
# test_recall : 0.870
# test_precision : 0.971
# test_f1_score : 0.918
# ******************************
# ==============================
# epoch : 60
# train_loss_mean : 0.074
# ******************************
# test_loss : 0.095
# test_iou : 0.896
# test_accuracy : 95.89%
# test_recall : 0.895
# test_precision : 0.947
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 61
# train_loss_mean : 0.076
# ******************************
# test_loss : 0.094
# test_iou : 0.895
# test_accuracy : 95.82%
# test_recall : 0.872
# test_precision : 0.967
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 62
# train_loss_mean : 0.071
# ******************************
# test_loss : 0.097
# test_iou : 0.892
# test_accuracy : 95.86%
# test_recall : 0.872
# test_precision : 0.969
# test_f1_score : 0.918
# ******************************
# ==============================
# epoch : 63
# train_loss_mean : 0.077
# ******************************
# test_loss : 0.094
# test_iou : 0.894
# test_accuracy : 95.78%
# test_recall : 0.879
# test_precision : 0.958
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 64
# train_loss_mean : 0.076
# ******************************
# test_loss : 0.094
# test_iou : 0.895
# test_accuracy : 95.82%
# test_recall : 0.866
# test_precision : 0.974
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 65
# train_loss_mean : 0.073
# ******************************
# test_loss : 0.089
# test_iou : 0.902
# test_accuracy : 96.23%
# test_recall : 0.906
# test_precision : 0.949
# test_f1_score : 0.927
# ******************************
# ==============================
# epoch : 66
# train_loss_mean : 0.073
# ******************************
# test_loss : 0.088
# test_iou : 0.903
# test_accuracy : 96.26%
# test_recall : 0.918
# test_precision : 0.939
# test_f1_score : 0.929
# ******************************
# ==============================
# epoch : 67
# train_loss_mean : 0.077
# ******************************
# test_loss : 0.095
# test_iou : 0.895
# test_accuracy : 95.86%
# test_recall : 0.889
# test_precision : 0.952
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 68
# train_loss_mean : 0.073
# ******************************
# test_loss : 0.089
# test_iou : 0.903
# test_accuracy : 96.15%
# test_recall : 0.891
# test_precision : 0.961
# test_f1_score : 0.925
# ******************************
# ==============================
# epoch : 69
# train_loss_mean : 0.067
# ******************************
# test_loss : 0.093
# test_iou : 0.898
# test_accuracy : 96.01%
# test_recall : 0.883
# test_precision : 0.963
# test_f1_score : 0.922
# ******************************
# ==============================
# epoch : 70
# train_loss_mean : 0.067
# ******************************
# test_loss : 0.089
# test_iou : 0.903
# test_accuracy : 96.28%
# test_recall : 0.897
# test_precision : 0.960
# test_f1_score : 0.927
# ******************************
# ==============================
# epoch : 71
# train_loss_mean : 0.069
# ******************************
# test_loss : 0.093
# test_iou : 0.898
# test_accuracy : 95.96%
# test_recall : 0.890
# test_precision : 0.955
# test_f1_score : 0.921
# ******************************
# ==============================
# epoch : 72
# train_loss_mean : 0.066
# ******************************
# test_loss : 0.093
# test_iou : 0.898
# test_accuracy : 96.02%
# test_recall : 0.893
# test_precision : 0.954
# test_f1_score : 0.923
# ******************************
# ==============================
# epoch : 73
# train_loss_mean : 0.070
# ******************************
# test_loss : 0.094
# test_iou : 0.897
# test_accuracy : 95.99%
# test_recall : 0.902
# test_precision : 0.945
# test_f1_score : 0.923
# ******************************
# ==============================
# epoch : 74
# train_loss_mean : 0.067
# ******************************
# test_loss : 0.087
# test_iou : 0.904
# test_accuracy : 96.21%
# test_recall : 0.899
# test_precision : 0.956
# test_f1_score : 0.926
# ******************************
# ==============================
# epoch : 75
# train_loss_mean : 0.065
# ******************************
# test_loss : 0.093
# test_iou : 0.898
# test_accuracy : 95.96%
# test_recall : 0.878
# test_precision : 0.967
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 76
# train_loss_mean : 0.067
# ******************************
# test_loss : 0.090
# test_iou : 0.901
# test_accuracy : 96.12%
# test_recall : 0.890
# test_precision : 0.961
# test_f1_score : 0.924
# ******************************
# ==============================
# epoch : 77
# train_loss_mean : 0.066
# ******************************
# test_loss : 0.102
# test_iou : 0.892
# test_accuracy : 95.86%
# test_recall : 0.892
# test_precision : 0.949
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 78
# train_loss_mean : 0.064
# ******************************
# test_loss : 0.111
# test_iou : 0.886
# test_accuracy : 95.69%
# test_recall : 0.861
# test_precision : 0.973
# test_f1_score : 0.914
# ******************************
# ==============================
# epoch : 79
# train_loss_mean : 0.070
# ******************************
# test_loss : 0.096
# test_iou : 0.895
# test_accuracy : 95.96%
# test_recall : 0.891
# test_precision : 0.953
# test_f1_score : 0.921
# ******************************
# ==============================
# epoch : 80
# train_loss_mean : 0.063
# ******************************
# test_loss : 0.094
# test_iou : 0.896
# test_accuracy : 95.95%
# test_recall : 0.877
# test_precision : 0.967
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 81
# train_loss_mean : 0.062
# ******************************
# test_loss : 0.094
# test_iou : 0.897
# test_accuracy : 96.06%
# test_recall : 0.908
# test_precision : 0.942
# test_f1_score : 0.924
# ******************************
# ==============================
# epoch : 82
# train_loss_mean : 0.072
# ******************************
# test_loss : 0.102
# test_iou : 0.893
# test_accuracy : 95.90%
# test_recall : 0.892
# test_precision : 0.951
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 83
# train_loss_mean : 0.067
# ******************************
# test_loss : 0.090
# test_iou : 0.903
# test_accuracy : 96.15%
# test_recall : 0.900
# test_precision : 0.952
# test_f1_score : 0.925
# ******************************
# ==============================
# epoch : 84
# train_loss_mean : 0.067
# ******************************
# test_loss : 0.096
# test_iou : 0.894
# test_accuracy : 95.90%
# test_recall : 0.876
# test_precision : 0.967
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 85
# train_loss_mean : 0.064
# ******************************
# test_loss : 0.102
# test_iou : 0.890
# test_accuracy : 95.71%
# test_recall : 0.858
# test_precision : 0.977
# test_f1_score : 0.914
# ******************************
# ==============================
# epoch : 86
# train_loss_mean : 0.064
# ******************************
# test_loss : 0.091
# test_iou : 0.904
# test_accuracy : 96.39%
# test_recall : 0.911
# test_precision : 0.951
# test_f1_score : 0.931
# ******************************
# ==============================
# epoch : 87
# train_loss_mean : 0.069
# ******************************
# test_loss : 0.104
# test_iou : 0.892
# test_accuracy : 95.91%
# test_recall : 0.878
# test_precision : 0.965
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 88
# train_loss_mean : 0.060
# ******************************
# test_loss : 0.096
# test_iou : 0.896
# test_accuracy : 95.97%
# test_recall : 0.874
# test_precision : 0.971
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 89
# train_loss_mean : 0.058
# ******************************
# test_loss : 0.094
# test_iou : 0.899
# test_accuracy : 96.15%
# test_recall : 0.897
# test_precision : 0.955
# test_f1_score : 0.925
# ******************************
# ==============================
# epoch : 90
# train_loss_mean : 0.060
# ******************************
# test_loss : 0.125
# test_iou : 0.877
# test_accuracy : 95.48%
# test_recall : 0.883
# test_precision : 0.943
# test_f1_score : 0.912
# ******************************
# ==============================
# epoch : 91
# train_loss_mean : 0.072
# ******************************
# test_loss : 0.126
# test_iou : 0.868
# test_accuracy : 95.02%
# test_recall : 0.845
# test_precision : 0.963
# test_f1_score : 0.900
# ******************************
# ==============================
# epoch : 92
# train_loss_mean : 0.061
# ******************************
# test_loss : 0.102
# test_iou : 0.896
# test_accuracy : 96.02%
# test_recall : 0.896
# test_precision : 0.952
# test_f1_score : 0.923
# ******************************
# ==============================
# epoch : 93
# train_loss_mean : 0.056
# ******************************
# test_loss : 0.109
# test_iou : 0.887
# test_accuracy : 95.72%
# test_recall : 0.865
# test_precision : 0.971
# test_f1_score : 0.915
# ******************************
# ==============================
# epoch : 94
# train_loss_mean : 0.059
# ******************************
# test_loss : 0.108
# test_iou : 0.888
# test_accuracy : 95.66%
# test_recall : 0.863
# test_precision : 0.970
# test_f1_score : 0.914
# ******************************
# ==============================
# epoch : 95
# train_loss_mean : 0.057
# ******************************
# test_loss : 0.103
# test_iou : 0.890
# test_accuracy : 95.69%
# test_recall : 0.865
# test_precision : 0.969
# test_f1_score : 0.914
# ******************************
# ==============================
# epoch : 96
# train_loss_mean : 0.056
# ******************************
# test_loss : 0.107
# test_iou : 0.896
# test_accuracy : 96.02%
# test_recall : 0.889
# test_precision : 0.958
# test_f1_score : 0.922
# ******************************
# ==============================
# epoch : 97
# train_loss_mean : 0.054
# ******************************
# test_loss : 0.109
# test_iou : 0.890
# test_accuracy : 95.87%
# test_recall : 0.879
# test_precision : 0.963
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 98
# train_loss_mean : 0.054
# ******************************
# test_loss : 0.098
# test_iou : 0.897
# test_accuracy : 96.00%
# test_recall : 0.884
# test_precision : 0.962
# test_f1_score : 0.921
# ******************************
# ==============================
# epoch : 99
# train_loss_mean : 0.055
# ******************************
# test_loss : 0.100
# test_iou : 0.898
# test_accuracy : 96.10%
# test_recall : 0.894
# test_precision : 0.956
# test_f1_score : 0.924
# ******************************

# %%
img_idx_list = [15 , 20 , 25 , 35 , 50 , 75 , 85]
for img_idx in img_idx_list:
    img_pred =  sess.run(y_pred , feed_dict = {inputs : np.expand_dims(x_test[img_idx] , axis = 0)  ,
                                keep_prob : 1 ,
                                on_train : False})

    fig , ax = plt.subplots(1 , 3 , figsize = (8 , 8))

    ax[0].imshow(x_test[img_idx] / 255.)
    ax[0].set_xticks([])
    ax[0].set_yticks([])
    ax[0].set_title('Original Image')

    ax[1].imshow(y_test[img_idx , : , : , 0] , plt.cm.binary_r)
    ax[1].set_xticks([])
    ax[1].set_yticks([])
    ax[1].set_title('Ground Truth')

    img_pred = np.round(img_pred)
    ax[2].imshow(img_pred[0 , : , : , 0] , plt.cm.binary_r)
    ax[2].set_xticks([])
    ax[2].set_yticks([])
    ax[2].set_title('Predicted Output')

# %%
saver = tf.train.Saver()
saver.save(sess , 'ATTU/ATTU_model')
print('Model Trained and Saved')
# Out:
# Model Trained and Saved
