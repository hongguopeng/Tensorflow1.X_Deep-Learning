# %% [markdown]
# ### 請解壓縮data.rar，取得本程式之數據

# %%
from google.colab import drive
# %tensorflow_version 1.x
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import numpy as np
from keras.layers import Conv2D , UpSampling2D , MaxPooling2D , concatenate
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import math
import cv2
import os

drive.mount('/content/gdrive')
path = os.path.join(os.getcwd() , 'gdrive' , 'My Drive' , 'unet_ISIC-2017')
os.chdir(path)
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
images = np.load('images.npy')
masks = np.load('masks.npy')
masks = np.expand_dims(masks , axis = -1)

(x_train , x_test , y_train , y_test) =\
train_test_split(images ,
                 masks,
                 test_size = 0.1 ,
                 random_state = 42)

del images , masks

# %%
def metrics(y_true , y_pred):
    y_true = np.reshape(y_true , [-1])
    y_pred = np.reshape(y_pred , [-1])
    y_true = np.where(y_true > 0.5 , 1 , 0)
    y_pred = np.where(y_pred > 0.5 , 1 , 0)
    cm = confusion_matrix(y_true , y_pred)
    accuracy = (cm[0 , 0] + cm[1 , 1]) / np.sum(cm)
    recall = cm[1 , 1] / (cm[1 , 0] + cm[1 , 1])
    precision = cm[1 , 1] / (cm[0 , 1] + cm[1 , 1])
    f1_score = 2 * recall * precision / (recall + precision)
    return accuracy , recall , precision , f1_score


def batch_norm_layer(inputs , on_train , convolution):
    # the dimension you wanna normalize, here [0] for batch
    # for image, you wanna do [0 , 1 , 2] for [batch , height , width] but not channel
    if convolution:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0 , 1 , 2] , name = 'mean_var')
    else:
        fc_mean , fc_var = tf.nn.moments(inputs , axes = [0] , name = 'mean_var')
    
    ema = tf.train.ExponentialMovingAverage(decay = 0.75)
    ema_apply_op = ema.apply([fc_mean , fc_var])
    mean = tf.cond(on_train , lambda : fc_mean , lambda : ema.average(fc_mean))
    var = tf.cond(on_train , lambda : fc_var , lambda : ema.average(fc_var))
    
    scale = tf.Variable(tf.ones([1 , inputs.shape[-1].value]) , name = 'scale') 
    shift = tf.Variable(tf.zeros([1 , inputs.shape[-1].value]) , name = 'shift')
    temp = (inputs - mean) / tf.sqrt(var + 0.001)
    outputs = tf.multiply(temp , scale) + shift
  
    return outputs , ema_apply_op


def recurrent_block(inputs , n_filter , steps = 1 , kernel_size = 3 , activation = tf.nn.relu ,
               padding = 'same' , kernel_initializer = 'glorot_uniform' , batch_norm = True):
    ema_list = []
    for step in range(0 , steps):

      if step == 0:
        conv = Conv2D(n_filter , kernel_size , activation = None , padding = padding ,
                      kernel_initializer = kernel_initializer)(inputs)

        if batch_norm: conv , ema = batch_norm_layer(conv , on_train , True)

        conv = activation(conv)

      else:
        conv = Conv2D(n_filter , kernel_size , activation = None , padding = padding ,
                      kernel_initializer = kernel_initializer)(conv + inputs)

        if batch_norm: conv , ema = batch_norm_layer(conv , on_train , True)

        conv = activation(conv)

      ema_list.append(ema)
    return conv , ema_list


def rrcnn_block(inputs , n_filter):
    conv_1x1 = Conv2D(n_filter , kernel_size = 1 , padding = 'same' , 
               kernel_initializer = 'glorot_uniform')(inputs)

    ema_list = []
    rec , ema1 = recurrent_block(conv_1x1 , n_filter)
    rec , ema2 = recurrent_block(rec , n_filter)
    ema_list.extend(ema1)
    ema_list.extend(ema2)           
    
    return rec + conv_1x1 , ema_list


def up_block(inputs , n_filter , kernel_size = 3 , activation =  tf.nn.relu ,
             padding = 'same' , kernel_initializer = 'glorot_uniform' , batch_norm = True):
    up_ = UpSampling2D(size = (2 , 2))(inputs)
    up = Conv2D(n_filter , kernel_size , activation = None , padding = padding ,
                kernel_initializer = kernel_initializer)(up_)

    if batch_norm: up , ema = batch_norm_layer(up , on_train , True)

    up = activation(up)
    return up , ema


def batch_generator(X , y , batch_size):
    size = X.shape[0]
    X_copy = X.copy()
    y_copy = y.copy()
    indices = np.arange(size)
    np.random.shuffle(indices)
    X_copy = X_copy[indices]
    y_copy = y_copy[indices]
    i = 0
    while True:
        if i + batch_size <= size:
            yield X_copy[i : i + batch_size] , y_copy[i : i + batch_size]
            i += batch_size
        else:
            i = 0
            indices = np.arange(size)
            np.random.shuffle(indices)
            X_copy = X_copy[indices]
            y_copy = y_copy[indices]

# %%
ema = []
inputs = tf.placeholder(tf.float32 , [None , 256 , 256 , 3] , name = 'inputs')
y_true = tf.placeholder(tf.float32 , [None , 256 , 256 , 1] , name = 'y_true')
keep_prob = tf.placeholder(tf.float32 , name = 'keep_prob')
on_train = tf.placeholder(tf.bool , name = 'on_train')

# %%
with tf.variable_scope('Encoder_Stage'):
    with tf.variable_scope('RRCNN1'):
        rrcnn1 , ema1 = rrcnn_block(inputs , 64)
        pool1 = MaxPooling2D(pool_size = (2 , 2))(rrcnn1)
        ema.extend(ema1)

    with tf.variable_scope('RRCNN2'):
        rrcnn2 , ema2 = rrcnn_block(pool1 , 128)
        pool2 = MaxPooling2D(pool_size = (2 , 2))(rrcnn2)
        ema.extend(ema2)
    
    with tf.variable_scope('RRCNN3'):
        rrcnn3 , ema3 = rrcnn_block(pool2 , 256)
        pool3 = MaxPooling2D(pool_size = (2 , 2))(rrcnn3)
        ema.extend(ema3)

    with tf.variable_scope('RRCNN4'):
        rrcnn4 , ema4 = rrcnn_block(pool3 , 512)
        pool4 = MaxPooling2D(pool_size = (2 , 2))(rrcnn4)
        ema.extend(ema4)


with tf.variable_scope('Middle_Stage'):
    rrcnn5 , ema5 = rrcnn_block(pool4 , 1024)
    drop5 = tf.nn.dropout(rrcnn5 , keep_prob)
    ema.extend(ema5)


with tf.variable_scope('Decoder_Stage'):
    with tf.variable_scope('RRCNN5'):
        up6 , ema6_1 = up_block(drop5 , 512)
        concat6 = concatenate([rrcnn4 , up6] , axis = -1)
        rrcnn6 , ema6_2 = rrcnn_block(concat6 , 512)
        ema.extend([ema6_1])
        ema.extend(ema6_2)

    with tf.variable_scope('RRCNN7'):
        up7 , ema7_1 = up_block(rrcnn6 , 256)
        concat7 = concatenate([rrcnn3 , up7] , axis = -1)
        rrcnn7 , ema7_2 = rrcnn_block(concat7 , 256)
        ema.extend([ema7_1])
        ema.extend(ema7_2)

    with tf.variable_scope('RRCNN8'):
        up8 , ema8_1 = up_block(rrcnn7 , 128)
        concat8 = concatenate([rrcnn2 , up8] , axis = -1)
        rrcnn8 , ema8_2 = rrcnn_block(concat8 , 128)
        ema.extend([ema8_1])
        ema.extend(ema8_2)

    with tf.variable_scope('RRCNN9'):
        up9 , ema9_1 = up_block(rrcnn8 , 64)
        concat9 = concatenate([rrcnn1 , up9] , axis = -1)
        rrcnn9 , ema9_2 = rrcnn_block(concat9 , 64)
        ema.extend([ema9_1])
        ema.extend(ema9_2)


with tf.variable_scope('Output_Stage'):
    y_pred = Conv2D(1 , 1 , activation = 'sigmoid' , padding = 'same' ,
                    kernel_initializer = 'glorot_uniform')(rrcnn9) 

with tf.variable_scope('Optimizer'):
    update_ema = tf.group(ema)
    cross_entropy = y_true * tf.log(tf.clip_by_value(y_pred , 1e-8 , tf.reduce_max(y_pred))) +\
                    (1 - y_true) * tf.log(tf.clip_by_value(1 - y_pred , 1e-8 , tf.reduce_max(1 - y_pred)))
    loss = -tf.reduce_mean(cross_entropy)
    train_op = tf.train.AdamOptimizer(1e-4).minimize(loss)

with tf.variable_scope('IOU'):
    smooth = 1e-8
    intersection = tf.reduce_sum(tf.abs(y_true * y_pred))
    sum_ = tf.reduce_sum(tf.square(y_true)) + tf.reduce_sum(tf.square(y_pred))
    iou = (intersection + smooth) / (sum_ - intersection + smooth)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From <ipython-input-5-efb08478b948>:25: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
image_grnerator = ImageDataGenerator(rotation_range = 0.1,
                                     width_shift_range = 0.1,
                                     height_shift_range = 0.1,
                                     shear_range = 0.02 ,
                                     zoom_range = 0.02,
                                     horizontal_flip = True ,
                                     fill_mode = 'nearest')

mask_grnerator = ImageDataGenerator(rotation_range = 0.1,
                                    width_shift_range = 0.1,
                                    height_shift_range = 0.1,
                                    shear_range = 0.02 ,
                                    zoom_range = 0.02,
                                    horizontal_flip = True ,
                                    fill_mode = 'nearest')

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

batch_size = 8
train_batch_generator = batch_generator(x_train , y_train , batch_size)
epochs = 100
num_batch = math.ceil(len(x_train) / batch_size)
for epoch_i in range(0 , epochs):
    train_loss_mean = 0
    for batch_i in range(0 , num_batch):
        x_train_bathch , y_train_bathch = next(train_batch_generator)
        x_train_bathch_aug = image_grnerator.flow(x_train_bathch , np.arange(8) , shuffle = False , batch_size = batch_size , seed = 1)
        y_train_bathch_aug = mask_grnerator.flow(y_train_bathch , np.arange(8) , shuffle = False , batch_size = batch_size , seed = 1)
        x_train_bathch_aug = x_train_bathch_aug[0][0]
        y_train_bathch_aug = y_train_bathch_aug[0][0]

        _ , _ , train_loss = sess.run([train_op , update_ema , loss] ,
                                      feed_dict = {inputs : x_train_bathch_aug ,
                                                   y_true : y_train_bathch_aug / 255. ,
                                                   keep_prob : 1 ,
                                                   on_train : True})
        train_loss_mean += train_loss

    print('=' * 30)
    print('epoch : {}'.format(epoch_i))
    print('train_loss_mean : {:.3f}'.format(train_loss_mean / num_batch))

    test_loss_sum = 0
    test_iou_sum = 0
    y_test_pred = np.zeros([len(x_test) , 256 , 256 , 1])
    for test_batch_i in range(0 , 10):
        test_loss , test_iou , y_test_pred_ =\
        sess.run([loss , iou , y_pred] ,
                feed_dict = {inputs : x_test[10*test_batch_i : 10*(test_batch_i+1)]  ,
                             y_true : y_test[10*test_batch_i : 10*(test_batch_i+1)]  / 255. ,
                             keep_prob : 1 ,
                             on_train : False})
        test_loss_sum += test_loss
        test_iou_sum += test_iou
        y_test_pred[10*test_batch_i : 10*(test_batch_i+1)]  = y_test_pred_

    accuracy_test , recall_test , precision_test , f1_score_test = metrics(y_test , y_test_pred)
    print('*' * 30)
    print('test_loss : {:.3f}'.format(test_loss_sum / 10))
    print('test_iou : {:.3f}'.format(test_iou_sum / 10))
    print('test_accuracy : {:.2%}'.format(accuracy_test))
    print('test_recall : {:.3f}'.format(recall_test))
    print('test_precision : {:.3f}'.format(precision_test))
    print('test_f1_score : {:.3f}'.format(f1_score_test))
    print('*' * 30)
# Out:
# ==============================
# epoch : 0
# train_loss_mean : 1.273
# ******************************
# test_loss : 0.890
# test_iou : 0.340
# test_accuracy : 81.16%
# test_recall : 0.297
# test_precision : 0.979
# test_f1_score : 0.455
# ******************************
# ==============================
# epoch : 1
# train_loss_mean : 0.391
# ******************************
# test_loss : 0.292
# test_iou : 0.629
# test_accuracy : 87.46%
# test_recall : 0.538
# test_precision : 0.982
# test_f1_score : 0.695
# ******************************
# ==============================
# epoch : 2
# train_loss_mean : 0.250
# ******************************
# test_loss : 0.350
# test_iou : 0.631
# test_accuracy : 88.53%
# test_recall : 0.576
# test_precision : 0.987
# test_f1_score : 0.727
# ******************************
# ==============================
# epoch : 3
# train_loss_mean : 0.208
# ******************************
# test_loss : 0.330
# test_iou : 0.672
# test_accuracy : 89.41%
# test_recall : 0.607
# test_precision : 0.990
# test_f1_score : 0.753
# ******************************
# ==============================
# epoch : 4
# train_loss_mean : 0.193
# ******************************
# test_loss : 0.217
# test_iou : 0.774
# test_accuracy : 92.25%
# test_recall : 0.725
# test_precision : 0.977
# test_f1_score : 0.832
# ******************************
# ==============================
# epoch : 5
# train_loss_mean : 0.179
# ******************************
# test_loss : 0.420
# test_iou : 0.614
# test_accuracy : 88.01%
# test_recall : 0.553
# test_precision : 0.991
# test_f1_score : 0.710
# ******************************
# ==============================
# epoch : 6
# train_loss_mean : 0.185
# ******************************
# test_loss : 0.143
# test_iou : 0.843
# test_accuracy : 94.27%
# test_recall : 0.816
# test_precision : 0.963
# test_f1_score : 0.883
# ******************************
# ==============================
# epoch : 7
# train_loss_mean : 0.200
# ******************************
# test_loss : 0.293
# test_iou : 0.696
# test_accuracy : 90.09%
# test_recall : 0.631
# test_precision : 0.993
# test_f1_score : 0.772
# ******************************
# ==============================
# epoch : 8
# train_loss_mean : 0.171
# ******************************
# test_loss : 0.137
# test_iou : 0.856
# test_accuracy : 94.66%
# test_recall : 0.861
# test_precision : 0.933
# test_f1_score : 0.895
# ******************************
# ==============================
# epoch : 9
# train_loss_mean : 0.157
# ******************************
# test_loss : 0.170
# test_iou : 0.821
# test_accuracy : 93.68%
# test_recall : 0.780
# test_precision : 0.977
# test_f1_score : 0.868
# ******************************
# ==============================
# epoch : 10
# train_loss_mean : 0.174
# ******************************
# test_loss : 0.197
# test_iou : 0.808
# test_accuracy : 92.46%
# test_recall : 0.961
# test_precision : 0.797
# test_f1_score : 0.871
# ******************************
# ==============================
# epoch : 11
# train_loss_mean : 0.157
# ******************************
# test_loss : 0.363
# test_iou : 0.653
# test_accuracy : 88.92%
# test_recall : 0.583
# test_precision : 0.999
# test_f1_score : 0.736
# ******************************
# ==============================
# epoch : 12
# train_loss_mean : 0.149
# ******************************
# test_loss : 0.141
# test_iou : 0.842
# test_accuracy : 94.06%
# test_recall : 0.812
# test_precision : 0.958
# test_f1_score : 0.879
# ******************************
# ==============================
# epoch : 13
# train_loss_mean : 0.150
# ******************************
# test_loss : 0.140
# test_iou : 0.835
# test_accuracy : 93.71%
# test_recall : 0.780
# test_precision : 0.979
# test_f1_score : 0.868
# ******************************
# ==============================
# epoch : 14
# train_loss_mean : 0.144
# ******************************
# test_loss : 0.145
# test_iou : 0.829
# test_accuracy : 93.62%
# test_recall : 0.773
# test_precision : 0.983
# test_f1_score : 0.866
# ******************************
# ==============================
# epoch : 15
# train_loss_mean : 0.136
# ******************************
# test_loss : 0.149
# test_iou : 0.828
# test_accuracy : 93.65%
# test_recall : 0.779
# test_precision : 0.977
# test_f1_score : 0.867
# ******************************
# ==============================
# epoch : 16
# train_loss_mean : 0.158
# ******************************
# test_loss : 0.144
# test_iou : 0.843
# test_accuracy : 94.01%
# test_recall : 0.862
# test_precision : 0.908
# test_f1_score : 0.884
# ******************************
# ==============================
# epoch : 17
# train_loss_mean : 0.155
# ******************************
# test_loss : 0.174
# test_iou : 0.830
# test_accuracy : 93.62%
# test_recall : 0.966
# test_precision : 0.824
# test_f1_score : 0.889
# ******************************
# ==============================
# epoch : 18
# train_loss_mean : 0.144
# ******************************
# test_loss : 0.117
# test_iou : 0.869
# test_accuracy : 95.04%
# test_recall : 0.846
# test_precision : 0.962
# test_f1_score : 0.901
# ******************************
# ==============================
# epoch : 19
# train_loss_mean : 0.134
# ******************************
# test_loss : 0.110
# test_iou : 0.879
# test_accuracy : 95.40%
# test_recall : 0.880
# test_precision : 0.943
# test_f1_score : 0.910
# ******************************
# ==============================
# epoch : 20
# train_loss_mean : 0.134
# ******************************
# test_loss : 0.135
# test_iou : 0.849
# test_accuracy : 94.36%
# test_recall : 0.805
# test_precision : 0.979
# test_f1_score : 0.883
# ******************************
# ==============================
# epoch : 21
# train_loss_mean : 0.128
# ******************************
# test_loss : 0.126
# test_iou : 0.864
# test_accuracy : 94.91%
# test_recall : 0.854
# test_precision : 0.950
# test_f1_score : 0.899
# ******************************
# ==============================
# epoch : 22
# train_loss_mean : 0.160
# ******************************
# test_loss : 0.146
# test_iou : 0.861
# test_accuracy : 95.06%
# test_recall : 0.959
# test_precision : 0.868
# test_f1_score : 0.912
# ******************************
# ==============================
# epoch : 23
# train_loss_mean : 0.132
# ******************************
# test_loss : 0.137
# test_iou : 0.860
# test_accuracy : 94.93%
# test_recall : 0.951
# test_precision : 0.870
# test_f1_score : 0.909
# ******************************
# ==============================
# epoch : 24
# train_loss_mean : 0.126
# ******************************
# test_loss : 0.489
# test_iou : 0.648
# test_accuracy : 82.33%
# test_recall : 0.993
# test_precision : 0.601
# test_f1_score : 0.749
# ******************************
# ==============================
# epoch : 25
# train_loss_mean : 0.136
# ******************************
# test_loss : 0.160
# test_iou : 0.816
# test_accuracy : 93.25%
# test_recall : 0.755
# test_precision : 0.988
# test_f1_score : 0.856
# ******************************
# ==============================
# epoch : 26
# train_loss_mean : 0.128
# ******************************
# test_loss : 0.193
# test_iou : 0.786
# test_accuracy : 92.44%
# test_recall : 0.718
# test_precision : 0.996
# test_f1_score : 0.834
# ******************************
# ==============================
# epoch : 27
# train_loss_mean : 0.136
# ******************************
# test_loss : 0.253
# test_iou : 0.763
# test_accuracy : 90.00%
# test_recall : 0.981
# test_precision : 0.733
# test_f1_score : 0.839
# ******************************
# ==============================
# epoch : 28
# train_loss_mean : 0.123
# ******************************
# test_loss : 0.112
# test_iou : 0.880
# test_accuracy : 95.61%
# test_recall : 0.915
# test_precision : 0.919
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 29
# train_loss_mean : 0.137
# ******************************
# test_loss : 0.111
# test_iou : 0.876
# test_accuracy : 95.25%
# test_recall : 0.867
# test_precision : 0.950
# test_f1_score : 0.907
# ******************************
# ==============================
# epoch : 30
# train_loss_mean : 0.132
# ******************************
# test_loss : 0.259
# test_iou : 0.768
# test_accuracy : 90.18%
# test_recall : 0.987
# test_precision : 0.734
# test_f1_score : 0.842
# ******************************
# ==============================
# epoch : 31
# train_loss_mean : 0.118
# ******************************
# test_loss : 0.138
# test_iou : 0.857
# test_accuracy : 94.60%
# test_recall : 0.943
# test_precision : 0.866
# test_f1_score : 0.903
# ******************************
# ==============================
# epoch : 32
# train_loss_mean : 0.122
# ******************************
# test_loss : 0.217
# test_iou : 0.791
# test_accuracy : 91.27%
# test_recall : 0.984
# test_precision : 0.759
# test_f1_score : 0.857
# ******************************
# ==============================
# epoch : 33
# train_loss_mean : 0.114
# ******************************
# test_loss : 0.138
# test_iou : 0.845
# test_accuracy : 94.15%
# test_recall : 0.798
# test_precision : 0.977
# test_f1_score : 0.879
# ******************************
# ==============================
# epoch : 34
# train_loss_mean : 0.116
# ******************************
# test_loss : 0.121
# test_iou : 0.868
# test_accuracy : 95.03%
# test_recall : 0.841
# test_precision : 0.967
# test_f1_score : 0.900
# ******************************
# ==============================
# epoch : 35
# train_loss_mean : 0.121
# ******************************
# test_loss : 0.220
# test_iou : 0.780
# test_accuracy : 92.32%
# test_recall : 0.718
# test_precision : 0.990
# test_f1_score : 0.832
# ******************************
# ==============================
# epoch : 36
# train_loss_mean : 0.127
# ******************************
# test_loss : 0.106
# test_iou : 0.884
# test_accuracy : 95.58%
# test_recall : 0.897
# test_precision : 0.934
# test_f1_score : 0.915
# ******************************
# ==============================
# epoch : 37
# train_loss_mean : 0.115
# ******************************
# test_loss : 0.128
# test_iou : 0.865
# test_accuracy : 95.03%
# test_recall : 0.953
# test_precision : 0.872
# test_f1_score : 0.910
# ******************************
# ==============================
# epoch : 38
# train_loss_mean : 0.110
# ******************************
# test_loss : 0.117
# test_iou : 0.866
# test_accuracy : 94.83%
# test_recall : 0.822
# test_precision : 0.980
# test_f1_score : 0.894
# ******************************
# ==============================
# epoch : 39
# train_loss_mean : 0.114
# ******************************
# test_loss : 0.100
# test_iou : 0.888
# test_accuracy : 95.70%
# test_recall : 0.885
# test_precision : 0.950
# test_f1_score : 0.916
# ******************************
# ==============================
# epoch : 40
# train_loss_mean : 0.106
# ******************************
# test_loss : 0.168
# test_iou : 0.834
# test_accuracy : 93.60%
# test_recall : 0.972
# test_precision : 0.820
# test_f1_score : 0.890
# ******************************
# ==============================
# epoch : 41
# train_loss_mean : 0.131
# ******************************
# test_loss : 0.192
# test_iou : 0.802
# test_accuracy : 92.98%
# test_recall : 0.741
# test_precision : 0.992
# test_f1_score : 0.849
# ******************************
# ==============================
# epoch : 42
# train_loss_mean : 0.112
# ******************************
# test_loss : 0.104
# test_iou : 0.882
# test_accuracy : 95.45%
# test_recall : 0.864
# test_precision : 0.961
# test_f1_score : 0.910
# ******************************
# ==============================
# epoch : 43
# train_loss_mean : 0.103
# ******************************
# test_loss : 0.098
# test_iou : 0.891
# test_accuracy : 95.83%
# test_recall : 0.886
# test_precision : 0.954
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 44
# train_loss_mean : 0.101
# ******************************
# test_loss : 0.263
# test_iou : 0.755
# test_accuracy : 89.09%
# test_recall : 0.991
# test_precision : 0.711
# test_f1_score : 0.828
# ******************************
# ==============================
# epoch : 45
# train_loss_mean : 0.106
# ******************************
# test_loss : 0.103
# test_iou : 0.888
# test_accuracy : 95.80%
# test_recall : 0.901
# test_precision : 0.938
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 46
# train_loss_mean : 0.105
# ******************************
# test_loss : 0.139
# test_iou : 0.860
# test_accuracy : 94.74%
# test_recall : 0.946
# test_precision : 0.868
# test_f1_score : 0.905
# ******************************
# ==============================
# epoch : 47
# train_loss_mean : 0.103
# ******************************
# test_loss : 0.102
# test_iou : 0.890
# test_accuracy : 95.89%
# test_recall : 0.921
# test_precision : 0.924
# test_f1_score : 0.923
# ******************************
# ==============================
# epoch : 48
# train_loss_mean : 0.103
# ******************************
# test_loss : 0.140
# test_iou : 0.847
# test_accuracy : 94.29%
# test_recall : 0.801
# test_precision : 0.981
# test_f1_score : 0.882
# ******************************
# ==============================
# epoch : 49
# train_loss_mean : 0.116
# ******************************
# test_loss : 0.397
# test_iou : 0.705
# test_accuracy : 86.65%
# test_recall : 0.985
# test_precision : 0.669
# test_f1_score : 0.797
# ******************************
# ==============================
# epoch : 50
# train_loss_mean : 0.128
# ******************************
# test_loss : 0.114
# test_iou : 0.873
# test_accuracy : 95.16%
# test_recall : 0.842
# test_precision : 0.972
# test_f1_score : 0.902
# ******************************
# ==============================
# epoch : 51
# train_loss_mean : 0.101
# ******************************
# test_loss : 0.104
# test_iou : 0.888
# test_accuracy : 95.87%
# test_recall : 0.930
# test_precision : 0.916
# test_f1_score : 0.923
# ******************************
# ==============================
# epoch : 52
# train_loss_mean : 0.106
# ******************************
# test_loss : 0.131
# test_iou : 0.857
# test_accuracy : 94.55%
# test_recall : 0.814
# test_precision : 0.977
# test_f1_score : 0.888
# ******************************
# ==============================
# epoch : 53
# train_loss_mean : 0.103
# ******************************
# test_loss : 0.109
# test_iou : 0.879
# test_accuracy : 95.32%
# test_recall : 0.846
# test_precision : 0.974
# test_f1_score : 0.906
# ******************************
# ==============================
# epoch : 54
# train_loss_mean : 0.096
# ******************************
# test_loss : 0.280
# test_iou : 0.752
# test_accuracy : 89.70%
# test_recall : 0.977
# test_precision : 0.728
# test_f1_score : 0.834
# ******************************
# ==============================
# epoch : 55
# train_loss_mean : 0.109
# ******************************
# test_loss : 0.276
# test_iou : 0.790
# test_accuracy : 92.89%
# test_recall : 0.749
# test_precision : 0.978
# test_f1_score : 0.848
# ******************************
# ==============================
# epoch : 56
# train_loss_mean : 0.126
# ******************************
# test_loss : 0.114
# test_iou : 0.876
# test_accuracy : 95.28%
# test_recall : 0.849
# test_precision : 0.969
# test_f1_score : 0.905
# ******************************
# ==============================
# epoch : 57
# train_loss_mean : 0.109
# ******************************
# test_loss : 0.102
# test_iou : 0.890
# test_accuracy : 96.01%
# test_recall : 0.921
# test_precision : 0.928
# test_f1_score : 0.925
# ******************************
# ==============================
# epoch : 58
# train_loss_mean : 0.090
# ******************************
# test_loss : 0.218
# test_iou : 0.784
# test_accuracy : 92.47%
# test_recall : 0.719
# test_precision : 0.997
# test_f1_score : 0.835
# ******************************
# ==============================
# epoch : 59
# train_loss_mean : 0.118
# ******************************
# test_loss : 0.112
# test_iou : 0.882
# test_accuracy : 95.60%
# test_recall : 0.910
# test_precision : 0.923
# test_f1_score : 0.916
# ******************************
# ==============================
# epoch : 60
# train_loss_mean : 0.088
# ******************************
# test_loss : 0.115
# test_iou : 0.878
# test_accuracy : 95.56%
# test_recall : 0.929
# test_precision : 0.906
# test_f1_score : 0.917
# ******************************
# ==============================
# epoch : 61
# train_loss_mean : 0.095
# ******************************
# test_loss : 0.114
# test_iou : 0.874
# test_accuracy : 95.00%
# test_recall : 0.907
# test_precision : 0.904
# test_f1_score : 0.906
# ******************************
# ==============================
# epoch : 62
# train_loss_mean : 0.087
# ******************************
# test_loss : 0.111
# test_iou : 0.877
# test_accuracy : 95.08%
# test_recall : 0.860
# test_precision : 0.950
# test_f1_score : 0.903
# ******************************
# ==============================
# epoch : 63
# train_loss_mean : 0.099
# ******************************
# test_loss : 0.109
# test_iou : 0.885
# test_accuracy : 95.75%
# test_recall : 0.922
# test_precision : 0.918
# test_f1_score : 0.920
# ******************************
# ==============================
# epoch : 64
# train_loss_mean : 0.095
# ******************************
# test_loss : 0.101
# test_iou : 0.884
# test_accuracy : 95.55%
# test_recall : 0.865
# test_precision : 0.963
# test_f1_score : 0.912
# ******************************
# ==============================
# epoch : 65
# train_loss_mean : 0.083
# ******************************
# test_loss : 0.096
# test_iou : 0.896
# test_accuracy : 96.18%
# test_recall : 0.918
# test_precision : 0.937
# test_f1_score : 0.927
# ******************************
# ==============================
# epoch : 66
# train_loss_mean : 0.090
# ******************************
# test_loss : 0.097
# test_iou : 0.893
# test_accuracy : 95.96%
# test_recall : 0.895
# test_precision : 0.949
# test_f1_score : 0.922
# ******************************
# ==============================
# epoch : 67
# train_loss_mean : 0.093
# ******************************
# test_loss : 0.229
# test_iou : 0.796
# test_accuracy : 93.04%
# test_recall : 0.743
# test_precision : 0.993
# test_f1_score : 0.850
# ******************************
# ==============================
# epoch : 68
# train_loss_mean : 0.098
# ******************************
# test_loss : 0.103
# test_iou : 0.880
# test_accuracy : 95.31%
# test_recall : 0.843
# test_precision : 0.977
# test_f1_score : 0.905
# ******************************
# ==============================
# epoch : 69
# train_loss_mean : 0.101
# ******************************
# test_loss : 0.133
# test_iou : 0.866
# test_accuracy : 95.12%
# test_recall : 0.909
# test_precision : 0.907
# test_f1_score : 0.908
# ******************************
# ==============================
# epoch : 70
# train_loss_mean : 0.098
# ******************************
# test_loss : 0.102
# test_iou : 0.890
# test_accuracy : 95.85%
# test_recall : 0.921
# test_precision : 0.923
# test_f1_score : 0.922
# ******************************
# ==============================
# epoch : 71
# train_loss_mean : 0.095
# ******************************
# test_loss : 0.102
# test_iou : 0.885
# test_accuracy : 95.55%
# test_recall : 0.869
# test_precision : 0.959
# test_f1_score : 0.912
# ******************************
# ==============================
# epoch : 72
# train_loss_mean : 0.085
# ******************************
# test_loss : 0.127
# test_iou : 0.854
# test_accuracy : 94.47%
# test_recall : 0.801
# test_precision : 0.989
# test_f1_score : 0.885
# ******************************
# ==============================
# epoch : 73
# train_loss_mean : 0.083
# ******************************
# test_loss : 0.108
# test_iou : 0.876
# test_accuracy : 95.15%
# test_recall : 0.838
# test_precision : 0.975
# test_f1_score : 0.902
# ******************************
# ==============================
# epoch : 74
# train_loss_mean : 0.083
# ******************************
# test_loss : 0.097
# test_iou : 0.895
# test_accuracy : 96.18%
# test_recall : 0.939
# test_precision : 0.918
# test_f1_score : 0.929
# ******************************
# ==============================
# epoch : 75
# train_loss_mean : 0.091
# ******************************
# test_loss : 0.114
# test_iou : 0.877
# test_accuracy : 95.38%
# test_recall : 0.900
# test_precision : 0.924
# test_f1_score : 0.912
# ******************************
# ==============================
# epoch : 76
# train_loss_mean : 0.098
# ******************************
# test_loss : 0.132
# test_iou : 0.855
# test_accuracy : 94.55%
# test_recall : 0.805
# test_precision : 0.987
# test_f1_score : 0.887
# ******************************
# ==============================
# epoch : 77
# train_loss_mean : 0.088
# ******************************
# test_loss : 0.097
# test_iou : 0.894
# test_accuracy : 95.93%
# test_recall : 0.914
# test_precision : 0.931
# test_f1_score : 0.923
# ******************************
# ==============================
# epoch : 78
# train_loss_mean : 0.087
# ******************************
# test_loss : 0.107
# test_iou : 0.884
# test_accuracy : 95.61%
# test_recall : 0.868
# test_precision : 0.962
# test_f1_score : 0.913
# ******************************
# ==============================
# epoch : 79
# train_loss_mean : 0.090
# ******************************
# test_loss : 0.113
# test_iou : 0.875
# test_accuracy : 95.17%
# test_recall : 0.836
# test_precision : 0.979
# test_f1_score : 0.902
# ******************************
# ==============================
# epoch : 80
# train_loss_mean : 0.081
# ******************************
# test_loss : 0.101
# test_iou : 0.891
# test_accuracy : 95.97%
# test_recall : 0.901
# test_precision : 0.944
# test_f1_score : 0.922
# ******************************
# ==============================
# epoch : 81
# train_loss_mean : 0.120
# ******************************
# test_loss : 0.136
# test_iou : 0.858
# test_accuracy : 94.50%
# test_recall : 0.849
# test_precision : 0.938
# test_f1_score : 0.891
# ******************************
# ==============================
# epoch : 82
# train_loss_mean : 0.091
# ******************************
# test_loss : 0.104
# test_iou : 0.883
# test_accuracy : 95.45%
# test_recall : 0.906
# test_precision : 0.921
# test_f1_score : 0.914
# ******************************
# ==============================
# epoch : 83
# train_loss_mean : 0.092
# ******************************
# test_loss : 0.098
# test_iou : 0.892
# test_accuracy : 95.78%
# test_recall : 0.902
# test_precision : 0.936
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 84
# train_loss_mean : 0.083
# ******************************
# test_loss : 0.156
# test_iou : 0.839
# test_accuracy : 94.05%
# test_recall : 0.785
# test_precision : 0.988
# test_f1_score : 0.875
# ******************************
# ==============================
# epoch : 85
# train_loss_mean : 0.084
# ******************************
# test_loss : 0.096
# test_iou : 0.895
# test_accuracy : 95.94%
# test_recall : 0.892
# test_precision : 0.952
# test_f1_score : 0.921
# ******************************
# ==============================
# epoch : 86
# train_loss_mean : 0.078
# ******************************
# test_loss : 0.116
# test_iou : 0.878
# test_accuracy : 95.54%
# test_recall : 0.949
# test_precision : 0.890
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 87
# train_loss_mean : 0.099
# ******************************
# test_loss : 0.095
# test_iou : 0.896
# test_accuracy : 96.09%
# test_recall : 0.921
# test_precision : 0.931
# test_f1_score : 0.926
# ******************************
# ==============================
# epoch : 88
# train_loss_mean : 0.076
# ******************************
# test_loss : 0.098
# test_iou : 0.893
# test_accuracy : 95.99%
# test_recall : 0.916
# test_precision : 0.932
# test_f1_score : 0.924
# ******************************
# ==============================
# epoch : 89
# train_loss_mean : 0.077
# ******************************
# test_loss : 0.124
# test_iou : 0.865
# test_accuracy : 94.75%
# test_recall : 0.880
# test_precision : 0.919
# test_f1_score : 0.899
# ******************************
# ==============================
# epoch : 90
# train_loss_mean : 0.083
# ******************************
# test_loss : 0.121
# test_iou : 0.866
# test_accuracy : 94.86%
# test_recall : 0.825
# test_precision : 0.977
# test_f1_score : 0.895
# ******************************
# ==============================
# epoch : 91
# train_loss_mean : 0.081
# ******************************
# test_loss : 0.117
# test_iou : 0.877
# test_accuracy : 95.48%
# test_recall : 0.953
# test_precision : 0.886
# test_f1_score : 0.918
# ******************************
# ==============================
# epoch : 92
# train_loss_mean : 0.084
# ******************************
# test_loss : 0.118
# test_iou : 0.875
# test_accuracy : 95.23%
# test_recall : 0.929
# test_precision : 0.895
# test_f1_score : 0.912
# ******************************
# ==============================
# epoch : 93
# train_loss_mean : 0.081
# ******************************
# test_loss : 0.118
# test_iou : 0.871
# test_accuracy : 95.07%
# test_recall : 0.832
# test_precision : 0.979
# test_f1_score : 0.900
# ******************************
# ==============================
# epoch : 94
# train_loss_mean : 0.079
# ******************************
# test_loss : 0.106
# test_iou : 0.884
# test_accuracy : 95.58%
# test_recall : 0.930
# test_precision : 0.906
# test_f1_score : 0.918
# ******************************
# ==============================
# epoch : 95
# train_loss_mean : 0.090
# ******************************
# test_loss : 0.132
# test_iou : 0.859
# test_accuracy : 94.53%
# test_recall : 0.922
# test_precision : 0.878
# test_f1_score : 0.899
# ******************************
# ==============================
# epoch : 96
# train_loss_mean : 0.078
# ******************************
# test_loss : 0.135
# test_iou : 0.851
# test_accuracy : 94.40%
# test_recall : 0.799
# test_precision : 0.988
# test_f1_score : 0.883
# ******************************
# ==============================
# epoch : 97
# train_loss_mean : 0.084
# ******************************
# test_loss : 0.140
# test_iou : 0.855
# test_accuracy : 94.52%
# test_recall : 0.927
# test_precision : 0.874
# test_f1_score : 0.900
# ******************************
# ==============================
# epoch : 98
# train_loss_mean : 0.092
# ******************************
# test_loss : 0.119
# test_iou : 0.876
# test_accuracy : 95.50%
# test_recall : 0.965
# test_precision : 0.877
# test_f1_score : 0.919
# ******************************
# ==============================
# epoch : 99
# train_loss_mean : 0.083
# ******************************
# test_loss : 0.104
# test_iou : 0.890
# test_accuracy : 95.84%
# test_recall : 0.888
# test_precision : 0.952
# test_f1_score : 0.919
# ******************************

# %%
img_idx_list = [15 , 20 , 25 , 35 , 50 , 75 , 85]
for img_idx in img_idx_list:
    img_pred =  sess.run(y_pred , feed_dict = {inputs : np.expand_dims(x_test[img_idx] , axis = 0)  ,
                                keep_prob : 1 ,
                                on_train : False})

    fig , ax = plt.subplots(1 , 3 , figsize = (8 , 8))

    ax[0].imshow(x_test[img_idx] / 255.)
    ax[0].set_xticks([])
    ax[0].set_yticks([])
    ax[0].set_title('Original Image')

    ax[1].imshow(y_test[img_idx , : , : , 0] , plt.cm.binary_r)
    ax[1].set_xticks([])
    ax[1].set_yticks([])
    ax[1].set_title('Ground Truth')

    img_pred = np.round(img_pred)
    ax[2].imshow(img_pred[0 , : , : , 0] , plt.cm.binary_r)
    ax[2].set_xticks([])
    ax[2].set_yticks([])
    ax[2].set_title('Predicted Output')

# %%
saver = tf.train.Saver()
saver.save(sess , 'unet/unet_model')
print('Model Trained and Saved')
# Out:
# Model Trained and Saved
